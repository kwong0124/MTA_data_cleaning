# %% [markdown]
# ### Exploratory Data Analysis with Python
#
# We will explore the NYC MTA turnstile data set. These data files are from the New York Subway. It tracks the hourly entries and exits to turnstiles (UNIT) by day in the subway system.
#
# Here is an [example of what you could do with the data](https://jameskao.me/analyzing-the-nyc-subway-dataset/). James Kao investigates how subway ridership is affected by incidence of rain.

# %% [markdown]
# ## Exercise 1
#
# - Download at least 2 weeks worth of [MTA turnstile data](http://web.mta.info/developers/turnstile.html) (You can do this manually or via Python)
# - Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
#
#         {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
#                  ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
#                 ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
#               ...
#          ]
#         }
#
# *Store all the weeks in a data structure of your choosing*

# %%
# information about the wget module here: https://pypi.python.org/pypi/wget

import wget

for date in ['170527', '170520', '170513', '170506']:
    url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt'.format(date)
    wget.download(url)
    print(date, 'file downloaded')
# Out:
# 170527 file downloaded
# 170520 file downloaded
# 170513 file downloaded
# 170506 file downloaded

# %%
import csv, glob # glob allows you to join files
from collections import defaultdict # lets you set a default dict value type - i.e. list

def read_csv(file):
    '''makes a dictionary of the mta data where, for each row, the key is the first four columns of data and the values
    are the rest of the columns'''
    turnstile_reading = defaultdict(list) # set the default value to list
    
    with open(file, 'r') as csv_file:
        mta_reader = csv.reader(csv_file)
        
        for i, row in enumerate(mta_reader): # returns a tuple with numbered items 
            if i == 0: # passes the header row (column names)
                continue
                
            turnstile_info = tuple(row[:4]) # grabs the first four items in the row
            count_reading = row[4:] # grabs items 5:end of the row
            turnstile_reading[turnstile_info].append(count_reading) # make a key value pair in the turnstile reading dict
            # where each key is the turnstile information and each value is the turnstile count
            
    return turnstile_reading

# %%
weekly_data_dicts = [read_csv(csvfile) for csvfile in glob.glob('turnstile_*.txt')] 
# returns all files that match the filename 'turnstile_*.txt' - the wildcard (*) is for the 
# dates which are different for each file. glob.glob returns each file 
# weekly_data_dicts is a list that contains dictionaries - one dictionary for each week of data
# in each dict, the keys are turnstile information and the values are the information for that 
# time period

# %%
print(len(weekly_data_dicts))
# Out:
# 4

# %%
sample_dict = list(weekly_data_dicts[0].items())[:2] # makes a list called sample_dict with the 
# which takes the first two items from the first dict in weekly_data_dicts
print(sample_dict)
# Out:
# [(('A002', 'R051', '02-00-00', '59 ST'), [['NQR456W', 'BMT', '04/29/2017', '00:00:00', 'REGULAR', '0006157740', '0002085315                                            '], ['NQR456W', 'BMT', '04/29/2017', '04:00:00', 'REGULAR', '0006157777', '0002085319                                            '], ['NQR456W', 'BMT', '04/29/2017', '08:00:00', 'REGULAR', '0006157810', '0002085353                                            '], ['NQR456W', 'BMT', '04/29/2017', '12:00:00', 'REGULAR', '0006157963', '0002085453                                            '], ['NQR456W', 'BMT', '04/29/2017', '16:00:00', 'REGULAR', '0006158212', '0002085529                                            '], ['NQR456W', 'BMT', '04/29/2017', '20:00:00', 'REGULAR', '0006158521', '0002085589                                            '], ['NQR456W', 'BMT', '04/30/2017', '00:00:00', 'REGULAR', '0006158637', '0002085612                                            '], ['NQR456W', 'BMT', '04/30/2017', '04:00:00', 'REGULAR', '0006158654', '0002085617                                            '], ['NQR456W', 'BMT', '04/30/2017', '08:00:00', 'REGULAR', '0006158661', '0002085641                                            '], ['NQR456W', 'BMT', '04/30/2017', '12:00:00', 'REGULAR', '0006158703', '0002085730                                            '], ['NQR456W', 'BMT', '04/30/2017', '16:00:00', 'REGULAR', '0006158797', '0002085785                                            '], ['NQR456W', 'BMT', '04/30/2017', '20:00:00', 'REGULAR', '0006159015', '0002085824                                            '], ['NQR456W', 'BMT', '05/01/2017', '00:00:00', 'REGULAR', '0006159107', '0002085842                                            '], ['NQR456W', 'BMT', '05/01/2017', '04:00:00', 'REGULAR', '0006159116', '0002085849                                            '], ['NQR456W', 'BMT', '05/01/2017', '08:00:00', 'REGULAR', '0006159166', '0002085976                                            '], ['NQR456W', 'BMT', '05/01/2017', '12:00:00', 'REGULAR', '0006159331', '0002086218                                            '], ['NQR456W', 'BMT', '05/01/2017', '16:00:00', 'REGULAR', '0006159595', '0002086299                                            '], ['NQR456W', 'BMT', '05/01/2017', '20:00:00', 'REGULAR', '0006160374', '0002086358                                            '], ['NQR456W', 'BMT', '05/02/2017', '00:00:00', 'REGULAR', '0006160508', '0002086374                                            '], ['NQR456W', 'BMT', '05/02/2017', '04:00:00', 'REGULAR', '0006160514', '0002086379                                            '], ['NQR456W', 'BMT', '05/02/2017', '08:00:00', 'REGULAR', '0006160555', '0002086499                                            '], ['NQR456W', 'BMT', '05/02/2017', '12:00:00', 'REGULAR', '0006160711', '0002086769                                            '], ['NQR456W', 'BMT', '05/02/2017', '16:00:00', 'REGULAR', '0006161012', '0002086835                                            '], ['NQR456W', 'BMT', '05/02/2017', '20:00:00', 'REGULAR', '0006161830', '0002086908                                            '], ['NQR456W', 'BMT', '05/03/2017', '00:00:00', 'REGULAR', '0006162061', '0002086933                                            '], ['NQR456W', 'BMT', '05/03/2017', '04:00:00', 'REGULAR', '0006162082', '0002086939                                            '], ['NQR456W', 'BMT', '05/03/2017', '08:00:00', 'REGULAR', '0006162129', '0002087070                                            '], ['NQR456W', 'BMT', '05/03/2017', '12:00:00', 'REGULAR', '0006162287', '0002087324                                            '], ['NQR456W', 'BMT', '05/03/2017', '16:00:00', 'REGULAR', '0006162575', '0002087391                                            '], ['NQR456W', 'BMT', '05/03/2017', '20:00:00', 'REGULAR', '0006163254', '0002087451                                            '], ['NQR456W', 'BMT', '05/04/2017', '00:00:00', 'REGULAR', '0006163517', '0002087485        ...

# %%
from pprint import pprint

pprint(sample_dict)
# Out:
# [(('A002', 'R051', '02-00-00', '59 ST'),
#   [['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006157740',
#     '0002085315                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006157777',
#     '0002085319                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006157810',
#     '0002085353                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006157963',
#     '0002085453                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006158212',
#     '0002085529                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006158521',
#     '0002085589                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006158637',
#     '0002085612                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006158654',
#     '0002085617                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006158661',
#     '0002085641                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006158703',
#     '0002085730                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006158797',
#     '0002085785                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006159015',
#     '0002085824                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006159107',
#     '0002085842                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006159116',
#     '0002085849                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006159166',
#     '0002085976                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006159331',
#     '0002086218                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006159595',
#     '0002086299                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006160374',
#     '0002086358                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006160508',
#     '0002086374                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006160514',
#     '0002086379                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006160555',
#     '0002086499                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006160711',
#     '0002086769                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006161012',
#     '0002086835                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006161830',
#     '0002086908                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006162061',
#     '0002086933                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006162082',
#     '0002086939                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006162129',
#     '0002087070                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006162287',
#     '0002087324                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006162575',
#     '0002087391                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006163254',
#     '0002087451                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006163517',
#     '0002087485                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006163534',
#     '0002087487                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006163576',
#     '0002087581                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006163739',
#     '0002087856                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006164051',
#     '0002087916                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006164865',
#     '0002087987                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '00:00:00',
#     'REGULAR',
#     '0006165120',
#     '0002088020                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '04:00:00',
#     'REGULAR',
#     '0006165147',
#     '0002088024                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '08:00:00',
#     'REGULAR',
#     '0006165183',
#     '0002088112                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '12:00:00',
#     'REGULAR',
#     '0006165346',
#     '0002088396                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '16:00:00',
#     'REGULAR',
#     '0006165481',
#     '0002088433                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '20:00:00',
#     'REGULAR',
#     '0006166192',
#     '0002088501                                            ']]),
#  (('A002', 'R051', '02-00-01', '59 ST'),
#   [['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005580416',
#     '0001235899                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005580437',
#     '0001235901                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005580462',
#     '0001235919                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005580581',
#     '0001235986                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005580766',
#     '0001236039                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/29/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005581062',
#     '0001236080                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005581232',
#     '0001236100                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005581273',
#     '0001236103                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005581282',
#     '0001236117                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005581337',
#     '0001236158                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005581572',
#     '0001236191                                            '],
#    ['NQR456W',
#     'BMT',
#     '04/30/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005581770',
#     '0001236214                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005581851',
#     '0001236228                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005581856',
#     '0001236231                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005581885',
#     '0001236295                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005582005',
#     '0001236404                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005582221',
#     '0001236472                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/01/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005582827',
#     '0001236530                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005583047',
#     '0001236546                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005583057',
#     '0001236548                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005583092',
#     '0001236592                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005583220',
#     '0001236719                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005583458',
#     '0001236773                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/02/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005584058',
#     '0001236827                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005584235',
#     '0001236847                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005584246',
#     '0001236849                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005584271',
#     '0001236911                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005584402',
#     '0001237035                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005584655',
#     '0001237071                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/03/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005585330',
#     '0001237144                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005585515',
#     '0001237160                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005585523',
#     '0001237163                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005585553',
#     '0001237213                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005585680',
#     '0001237354                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005585926',
#     '0001237400                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/04/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005586565',
#     '0001237461                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '00:00:00',
#     'REGULAR',
#     '0005586785',
#     '0001237486                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '04:00:00',
#     'REGULAR',
#     '0005586799',
#     '0001237489                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '08:00:00',
#     'REGULAR',
#     '0005586824',
#     '0001237531                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '12:00:00',
#     'REGULAR',
#     '0005586962',
#     '0001237673                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '16:00:00',
#     'REGULAR',
#     '0005587071',
#     '0001237697                                            '],
#    ['NQR456W',
#     'BMT',
#     '05/05/2017',
#     '20:00:00',
#     'REGULAR',
#     '0005587654',
#     '0001237743                                            ']])]

# %% [markdown]
# ## Exercise 2
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the cumulative count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the [dateutil](https://dateutil.readthedocs.io/en/stable/) module to convert it into a datetime object.
#
# Your new dict should look something like
#
#     {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                 [datetime.datetime(2013, 3, 2, 3, 0), 3788],
#                 [datetime.datetime(2013, 3, 2, 7, 0), 2585],
#                 [datetime.datetime(2013, 3, 2, 12, 0), 10653],
#                 [datetime.datetime(2013, 3, 2, 17, 0), 11016],
#                 [datetime.datetime(2013, 3, 2, 23, 0), 10666],
#                 [datetime.datetime(2013, 3, 3, 3, 0), 10814],
#                 [datetime.datetime(2013, 3, 3, 7, 0), 10229],
#                 ...
#               ],
#      ....
#      }

# %%
from datetime import datetime
from dateutil.parser import parse

def convert_to_time_series(week_data_dict):
    '''take a dictionary of information about each turnstile and returns a new dict  
    containing the turnstile (key) and the timestamp and cumulative entries as the values'''
    time_series = defaultdict(list) # sets the default dict to list - creates an empty list for each key initialized
    
    for i, (turnstile, row_data) in enumerate(week_data_dict.items()):
        if i % 100 == 0:
            print('Processing turnstile: ', turnstile)
        for linename, division, date, time, desc, cum_entries, cum_exits in row_data:
            timestamp = parse('%sT%s' %(date, time))
            time_series[turnstile].append([timestamp, int(cum_entries)])
            
    return time_series

# %%
weekly_time_series = list(map(convert_to_time_series, weekly_data_dicts)) # map applies the 
# specified function (convert_to_time_series) to each item in a list (weekly_data_dicts)
# Out:
# Processing turnstile:  ('A002', 'R051', '02-00-00', '59 ST')
# Processing turnstile:  ('A030', 'R083', '01-06-00', '23 ST')
# Processing turnstile:  ('A049', 'R088', '02-01-01', 'CORTLANDT ST')
# Processing turnstile:  ('A084', 'R125', '01-00-03', 'BROAD ST')
# Processing turnstile:  ('B024', 'R211', '00-00-03', 'KINGS HWY')
# Processing turnstile:  ('C012', 'R258', '01-03-01', '4AV-9 ST')
# Processing turnstile:  ('E001', 'R368', '00-00-03', '9 AV')
# Processing turnstile:  ('H007', 'R248', '00-03-01', '1 AV')
# Processing turnstile:  ('H040', 'R376', '00-00-01', 'EAST 105 ST')
# Processing turnstile:  ('J030', 'R005', '00-00-03', '85 ST-FOREST PK')
# Processing turnstile:  ('N013', 'R035', '02-00-04', '168 ST')
# Processing turnstile:  ('N049', 'R084', '01-02-02', '59 ST COLUMBUS')
# Processing turnstile:  ('N067', 'R012', '00-05-01', '34 ST-PENN STA')
# Processing turnstile:  ('N089', 'R139', '00-03-01', 'CANAL ST')
# Processing turnstile:  ('N102', 'R127', '01-05-01', 'JAY ST-METROTEC')
# Processing turnstile:  ('N125', 'R440', '00-00-01', 'LIBERTY AV')
# Processing turnstile:  ('N191', 'R335', '00-00-00', 'BEACH 67 ST')
# Processing turnstile:  ('N218', 'R112', '01-06-01', 'FORDHAM RD')
# Processing turnstile:  ('N309A', 'R140', '00-00-03', 'QUEENS PLAZA')
# Processing turnstile:  ('N325A', 'R218', '00-06-02', 'ELMHURST AV')
# Processing turnstile:  ('N336', 'R158', '00-05-00', 'KEW GARDENS')
# Processing turnstile:  ('N408A', 'R256', '00-00-02', 'NASSAU AV')
# Processing turnstile:  ('N503', 'R021', '00-00-01', '42 ST-BRYANT PK')
# Processing turnstile:  ('N519A', 'R461', '01-06-01', "B'WAY-LAFAYETTE")
# Processing turnstile:  ('N542', 'R241', '00-05-00', '15 ST-PROSPECT')
# Processing turnstile:  ('N601A', 'R319', '01-03-03', 'LEXINGTON AV/63')
# Processing turnstile:  ('N702A', 'R572', '01-03-01', '96 ST-2 AVE')
# Processing turnstile:  ('PTH05', 'R543', '00-04-07', 'EXCHANGE PLACE')
# Processing turnstile:  ('PTH16', 'R550', '01-01-07', 'LACKAWANNA')
# Processing turnstile:  ('PTH22', 'R540', '02-02-00', 'PATH NEW WTC')
# Processing turnstile:  ('R116', 'R030', '00-05-01', 'CHAMBERS ST')
# Processing turnstile:  ('R138', 'R293', '00-03-02', '34 ST-PENN STA')
# Processing turnstile:  ('R159', 'R164', '01-00-00', '66 ST-LINCOLN')
# Processing turnstile:  ('R172', 'R192', '00-00-02', 'CATHEDRAL PKWY')
# Processing turnstile:  ('R200A', 'R041', '01-05-00', 'BOWLING GREEN')
# Processing turnstile:  ('R217A', 'R194', '00-00-02', 'BLEECKER ST')
# Processing turnstile:  ('R236', 'R045', '00-00-05', 'GRD CNTRL-42 ST')
# Processing turnstile:  ('R244A', 'R050', '01-06-01', '59 ST')
# Processing turnstile:  ('R258', 'R132', '00-03-03', '125 ST')
# Processing turnstile:  ('R302', 'R324', '01-00-04', '116 ST')
# Processing turnstile:  ('R327', 'R361', '01-05-01', 'PELHAM PKWY')
# Processing turnstile:  ('R415', 'R120', '00-05-00', 'MORISN AV/SNDVW')
# Processing turnstile:  ('R509', 'R121', '00-00-02', 'QUEENSBORO PLZ')
# Processing turnstile:  ('R526', 'R096', '00-03-01', '82 ST-JACKSON H')
# Processing turnstile:  ('R534', 'R055', '01-03-03', 'FLUSHING-MAIN')
# Processing turnstile:  ('R612', 'R057', '01-03-00', 'ATL AV-BARCLAY')
# Processing turnstile:  ('R639', 'R109', '00-05-02', 'CHURCH AV')
# Processing turnstile:  ('A002', 'R051', '02-00-00', '59 ST')
# Processing turnstile:  ('A030', 'R083', '01-06-00', '23 ST')
# Processing turnstile:  ('A049', 'R088', '02-01-01', 'CORTLANDT ST')
# Processing turnstile:  ('A084', 'R125', '01-00-03', 'BROAD ST')
# Processing turnstile:  ('B024', 'R211', '00-05-00', 'KINGS HWY')
# Processing turnstile:  ('C012', 'R258', '01-03-02', '4AV-9 ST')
# Processing turnstile:  ('E003', 'R369', '00-03-00', 'FT HAMILTON PKY')
# Processing turnstile:  ('H009', 'R235', '00-00-00', 'BEDFORD AV')
# Processing turnstile:  ('H041', 'R152', '00-00-04', 'CANARSIE-ROCKAW')
# Processing turnstile:  ('J032', 'R006', '01-06-00', 'WOODHAVEN BLVD')
# Processing turnstile:  ('N016A', 'R296', '00-03-01', '163 ST-AMSTERDM')
# Processing turnstile:  ('N049', 'R084', '01-06-00', '59 ST COLUMBUS')
# Processing turnstile:  ('N069', 'R013', '01-00-00', '34 ST-PENN STA')
# Processing turnstile:  ('N089', 'R139', '00-06-02', 'CANAL ST')
# Processing turnstile:  ('N103', 'R127', '00-00-03', 'JAY ST-METROTEC')
# Processing turnstile:  ('N127', 'R442', '00-00-02', 'SHEPHERD AV')
# Processing turnstile:  ('N192', 'R336', '00-00-02', 'BEACH 60 ST')
# Processing turnstile:  ('N220', 'R155', '01-06-01', 'KINGSBRIDGE RD')
# Processing turnstile:  ('N309A', 'R140', '00-03-02', 'QUEENS PLAZA')
# Processing turnstile:  ('N327', 'R254', '00-05-03', 'GRAND-NEWTOWN')
# Processing turnstile:  ('N337', 'R255', '00-03-01', 'BRIARWOOD')
# Processing turnstile:  ('N409', 'R268', '00-00-01', 'METROPOLITAN AV')
# Processing turnstile:  ('N504', 'R021', '02-00-03', '42 ST-BRYANT PK')
# Processing turnstile:  ('N520', 'R240', '00-00-07', 'GRAND ST')
# Processing turnstile:  ('N544', 'R289', '01-05-01', 'FT HAMILTON PKY')
# Processing turnstile:  ('N602', 'R259', '00-05-01', 'ROOSEVELT ISLND')
# Processing turnstile:  ('PTH01', 'R549', '00-00-04', 'NEWARK HW BMEBE')
# Processing turnstile:  ('PTH06', 'R546', '00-00-05', 'PAVONIA/NEWPORT')
# Processing turnstile:  ('PTH17', 'R541', '01-00-01', 'THIRTY THIRD ST')
# Processing turnstile:  ('PTH22', 'R540', '02-03-00', 'PATH NEW WTC')
# Processing turnstile:  ('R117', 'R343', '00-00-01', 'FRANKLIN ST')
# Processing turnstile:  ('R139', 'R031', '04-00-00', '34 ST-PENN STA')
# Processing turnstile:  ('R159', 'R164', '01-06-01', '66 ST-LINCOLN')
# Processing turnstile:  ('R174', 'R034', '00-00-00', '125 ST')
# Processing turnstile:  ('R201', 'R041', '00-03-03', 'BOWLING GREEN')
# Processing turnstile:  ('R219', 'R160', '00-00-01', 'ASTOR PL')
# Processing turnstile:  ('R237', 'R046', '01-00-01', 'GRD CNTRL-42 ST')
# Processing turnstile:  ('R245', 'R051', '00-05-02', '59 ST')
# Processing turnstile:  ('R259', 'R307', '00-00-02', '138/GRAND CONC')
# Processing turnstile:  ('R304', 'R206', '00-00-04', '125 ST')
# Processing turnstile:  ('R329', 'R362', '00-00-00', 'ALLERTON AV')
# Processing turnstile:  ('R417', 'R222', '00-00-00', 'PARKCHESTER')
# Processing turnstile:  ('R511', 'R091', '00-00-01', '36 AV')
# Processing turnstile:  ('R527', 'R122', '00-00-01', '90 ST-ELMHURST')
# Processing turnstile:  ('R550', 'R072', '00-00-03', '34 ST-HUDSON YD')
# Processing turnstile:  ('R612', 'R057', '01-05-01', 'ATL AV-BARCLAY')
# Processing turnstile:  ('R643', 'R135', '00-00-01', 'NEWKIRK AV')
# Processing turnstile:  ('A002', 'R051', '02-00-00', '59 ST')
# Processing turnstile:  ('A030', 'R083', '01-06-00', '23 ST')
# Processing turnstile:  ('A049', 'R088', '02-01-01', 'CORTLANDT ST')
# Processing turnstile:  ('A084', 'R125', '01-00-03', 'BROAD ST')
# Processing turnstile:  ('B024', 'R211', '00-00-03', 'KINGS HWY')
# Processing turnstile:  ('C012', 'R258', '01-03-01', '4AV-9 ST')
# Processing turnstile:  ('E003', 'R369', '00-00-02', 'FT HAMILTON PKY')
# Processing turnstile:  ('H008', 'R248', '01-00-04', '1 AV')
# Processing turnstile:  ('H041', 'R152', '00-00-03', 'CANARSIE-ROCKAW')
# Processing turnstile:  ('J032', 'R006', '01-05-01', 'WOODHAVEN BLVD')
# Processing turnstile:  ('N016A', 'R296', '00-03-00', '163 ST-AMSTERDM')
# Processing turnstile:  ('N049', 'R084', '01-05-01', '59 ST COLUMBUS')
# Processing turnstile:  ('N068', 'R012', '03-06-00', '34 ST-PENN STA')
# Processing turnstile:  ('N089', 'R139', '00-06-01', 'CANAL ST')
# Processing turnstile:  ('N103', 'R127', '00-00-02', 'JAY ST-METROTEC')
# Processing turnstile:  ('N127', 'R442', '00-00-01', 'SHEPHERD AV')
# Processing turnstile:  ('N192', 'R336', '00-00-01', 'BEACH 60 ST')
# Processing turnstile:  ('N220', 'R155', '01-06-00', 'KINGSBRIDGE RD')
# Processing turnstile:  ('N309A', 'R140', '00-03-01', 'QUEENS PLAZA')
# Processing turnstile:  ('N327', 'R254', '00-05-02', 'GRAND-NEWTOWN')
# Processing turnstile:  ('N337', 'R255', '00-03-00', 'BRIARWOOD')
# Processing turnstile:  ('N409', 'R268', '00-00-00', 'METROPOLITAN AV')
# Processing turnstile:  ('N504', 'R021', '02-00-02', '42 ST-BRYANT PK')
# Processing turnstile:  ('N520', 'R240', '00-00-06', 'GRAND ST')
# Processing turnstile:  ('N544', 'R289', '01-05-00', 'FT HAMILTON PKY')
# Processing turnstile:  ('N602', 'R259', '00-05-00', 'ROOSEVELT ISLND')
# Processing turnstile:  ('PTH01', 'R549', '00-00-03', 'NEWARK HW BMEBE')
# Processing turnstile:  ('PTH06', 'R546', '00-00-04', 'PAVONIA/NEWPORT')
# Processing turnstile:  ('PTH16', 'R550', '01-02-04', 'LACKAWANNA')
# Processing turnstile:  ('PTH22', 'R540', '02-02-06', 'PATH NEW WTC')
# Processing turnstile:  ('R116', 'R030', '00-06-03', 'CHAMBERS ST')
# Processing turnstile:  ('R138', 'R293', '00-05-01', '34 ST-PENN STA')
# Processing turnstile:  ('R159', 'R164', '01-05-01', '66 ST-LINCOLN')
# Processing turnstile:  ('R173', 'R159', '00-03-00', '116 ST-COLUMBIA')
# Processing turnstile:  ('R201', 'R041', '00-03-01', 'BOWLING GREEN')
# Processing turnstile:  ('R217A', 'R194', '00-05-02', 'BLEECKER ST')
# Processing turnstile:  ('R236', 'R045', '00-06-01', 'GRD CNTRL-42 ST')
# Processing turnstile:  ('R245A', 'R051', '01-06-01', '59 ST')
# Processing turnstile:  ('R261', 'R205', '00-00-01', '149/GRAND CONC')
# Processing turnstile:  ('R306', 'R207', '00-00-02', '135 ST')
# Processing turnstile:  ('R331', 'R364', '00-00-00', 'GUN HILL RD')
# Processing turnstile:  ('R417', 'R222', '00-03-01', 'PARKCHESTER')
# Processing turnstile:  ('R512', 'R092', '00-03-00', 'BROADWAY')
# Processing turnstile:  ('R527', 'R122', '00-05-00', '90 ST-ELMHURST')
# Processing turnstile:  ('R550', 'R072', '00-03-05', '34 ST-HUDSON YD')
# Processing turnstile:  ('R618', 'R058', '01-00-02', 'BERGEN ST')
# Processing turnstile:  ('R644', 'R135', '01-00-02', 'NEWKIRK AV')
# Processing turnstile:  ('A002', 'R051', '02-00-00', '59 ST')
# Processing turnstile:  ('A030', 'R083', '01-06-00', '23 ST')
# Processing turnstile:  ('A049', 'R088', '02-01-01', 'CORTLANDT ST')
# Processing turnstile:  ('A084', 'R125', '01-00-03', 'BROAD ST')
# Processing turnstile:  ('B024', 'R211', '00-00-03', 'KINGS HWY')
# Processing turnstile:  ('C012', 'R258', '01-03-01', '4AV-9 ST')
# Processing turnstile:  ('E003', 'R369', '00-00-02', 'FT HAMILTON PKY')
# Processing turnstile:  ('H008', 'R248', '01-00-04', '1 AV')
# Processing turnstile:  ('H041', 'R152', '00-00-03', 'CANARSIE-ROCKAW')
# Processing turnstile:  ('J034', 'R007', '00-00-00', '104 ST')
# Processing turnstile:  ('N017', 'R331', '00-00-00', '155 ST')
# Processing turnstile:  ('N049', 'R084', '01-06-02', '59 ST COLUMBUS')
# Processing turnstile:  ('N069', 'R013', '01-00-02', '34 ST-PENN STA')
# Processing turnstile:  ('N090', 'R139', '01-00-01', 'CANAL ST')
# Processing turnstile:  ('N103', 'R127', '00-00-05', 'JAY ST-METROTEC')
# Processing turnstile:  ('N128', 'R200', '00-00-01', 'EUCLID AV')
# Processing turnstile:  ('N192', 'R336', '00-05-01', 'BEACH 60 ST')
# Processing turnstile:  ('N221', 'R155', '00-00-01', 'KINGSBRIDGE RD')
# Processing turnstile:  ('N309A', 'R140', '00-05-01', 'QUEENS PLAZA')
# Processing turnstile:  ('N327', 'R254', '00-06-00', 'GRAND-NEWTOWN')
# Processing turnstile:  ('N338', 'R128', '01-05-00', 'SUTPHIN BLVD')
# Processing turnstile:  ('N409', 'R268', '00-03-00', 'METROPOLITAN AV')
# Processing turnstile:  ('N504', 'R021', '02-00-05', '42 ST-BRYANT PK')
# Processing turnstile:  ('N521', 'R300', '01-00-01', '2 AV')
# Processing turnstile:  ('N544', 'R289', '01-06-01', 'FT HAMILTON PKY')
# Processing turnstile:  ('N602', 'R259', '00-05-01', 'ROOSEVELT ISLND')
# Processing turnstile:  ('OB01', 'R459', '00-03-01', 'ORCHARD BEACH')
# Processing turnstile:  ('PTH06', 'R546', '00-00-00', 'PAVONIA/NEWPORT')
# Processing turnstile:  ('PTH17', 'R541', '01-00-04', 'THIRTY THIRD ST')
# Processing turnstile:  ('PTH22', 'R540', '02-03-03', 'PATH NEW WTC')
# Processing turnstile:  ('R118', 'R343', '01-00-01', 'FRANKLIN ST')
# Processing turnstile:  ('R139', 'R031', '04-00-03', '34 ST-PENN STA')
# Processing turnstile:  ('R160', 'R164', '02-00-02', '66 ST-LINCOLN')
# Processing turnstile:  ('R174', 'R034', '00-00-03', '125 ST')
# Processing turnstile:  ('R201', 'R041', '00-05-01', 'BOWLING GREEN')
# Processing turnstile:  ('R219', 'R160', '00-00-04', 'ASTOR PL')
# Processing turnstile:  ('R237', 'R046', '01-00-04', 'GRD CNTRL-42 ST')
# Processing turnstile:  ('R246', 'R177', '00-00-04', '68ST-HUNTER CO')
# Processing turnstile:  ('R262', 'R195', '03-03-00', '161/YANKEE STAD')
# Processing turnstile:  ('R307', 'R207', '01-00-00', '135 ST')
# Processing turnstile:  ('R331', 'R364', '00-05-01', 'GUN HILL RD')
# Processing turnstile:  ('R417', 'R222', '00-05-01', 'PARKCHESTER')
# Processing turnstile:  ('R513', 'R093', '00-00-02', '30 AV')
# Processing turnstile:  ('R528', 'R097', '00-00-03', 'JUNCTION BLVD')
# Processing turnstile:  ('R550', 'R072', '00-03-0A', '34 ST-HUDSON YD')
# Processing turnstile:  ('R619', 'R059', '00-03-00', 'GRAND ARMY PLAZ')
# Processing turnstile:  ('R645', 'R110', '00-03-00', 'FLATBUSH AV-B.C')

# %%
sample = list(weekly_time_series[0].items())[0:5]
pprint(sample)
# Out:
# [(('A002', 'R051', '02-00-00', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 6157740],
#    [datetime.datetime(2017, 4, 29, 4, 0), 6157777],
#    [datetime.datetime(2017, 4, 29, 8, 0), 6157810],
#    [datetime.datetime(2017, 4, 29, 12, 0), 6157963],
#    [datetime.datetime(2017, 4, 29, 16, 0), 6158212],
#    [datetime.datetime(2017, 4, 29, 20, 0), 6158521],
#    [datetime.datetime(2017, 4, 30, 0, 0), 6158637],
#    [datetime.datetime(2017, 4, 30, 4, 0), 6158654],
#    [datetime.datetime(2017, 4, 30, 8, 0), 6158661],
#    [datetime.datetime(2017, 4, 30, 12, 0), 6158703],
#    [datetime.datetime(2017, 4, 30, 16, 0), 6158797],
#    [datetime.datetime(2017, 4, 30, 20, 0), 6159015],
#    [datetime.datetime(2017, 5, 1, 0, 0), 6159107],
#    [datetime.datetime(2017, 5, 1, 4, 0), 6159116],
#    [datetime.datetime(2017, 5, 1, 8, 0), 6159166],
#    [datetime.datetime(2017, 5, 1, 12, 0), 6159331],
#    [datetime.datetime(2017, 5, 1, 16, 0), 6159595],
#    [datetime.datetime(2017, 5, 1, 20, 0), 6160374],
#    [datetime.datetime(2017, 5, 2, 0, 0), 6160508],
#    [datetime.datetime(2017, 5, 2, 4, 0), 6160514],
#    [datetime.datetime(2017, 5, 2, 8, 0), 6160555],
#    [datetime.datetime(2017, 5, 2, 12, 0), 6160711],
#    [datetime.datetime(2017, 5, 2, 16, 0), 6161012],
#    [datetime.datetime(2017, 5, 2, 20, 0), 6161830],
#    [datetime.datetime(2017, 5, 3, 0, 0), 6162061],
#    [datetime.datetime(2017, 5, 3, 4, 0), 6162082],
#    [datetime.datetime(2017, 5, 3, 8, 0), 6162129],
#    [datetime.datetime(2017, 5, 3, 12, 0), 6162287],
#    [datetime.datetime(2017, 5, 3, 16, 0), 6162575],
#    [datetime.datetime(2017, 5, 3, 20, 0), 6163254],
#    [datetime.datetime(2017, 5, 4, 0, 0), 6163517],
#    [datetime.datetime(2017, 5, 4, 4, 0), 6163534],
#    [datetime.datetime(2017, 5, 4, 8, 0), 6163576],
#    [datetime.datetime(2017, 5, 4, 12, 0), 6163739],
#    [datetime.datetime(2017, 5, 4, 16, 0), 6164051],
#    [datetime.datetime(2017, 5, 4, 20, 0), 6164865],
#    [datetime.datetime(2017, 5, 5, 0, 0), 6165120],
#    [datetime.datetime(2017, 5, 5, 4, 0), 6165147],
#    [datetime.datetime(2017, 5, 5, 8, 0), 6165183],
#    [datetime.datetime(2017, 5, 5, 12, 0), 6165346],
#    [datetime.datetime(2017, 5, 5, 16, 0), 6165481],
#    [datetime.datetime(2017, 5, 5, 20, 0), 6166192]]),
#  (('A002', 'R051', '02-00-01', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 5580416],
#    [datetime.datetime(2017, 4, 29, 4, 0), 5580437],
#    [datetime.datetime(2017, 4, 29, 8, 0), 5580462],
#    [datetime.datetime(2017, 4, 29, 12, 0), 5580581],
#    [datetime.datetime(2017, 4, 29, 16, 0), 5580766],
#    [datetime.datetime(2017, 4, 29, 20, 0), 5581062],
#    [datetime.datetime(2017, 4, 30, 0, 0), 5581232],
#    [datetime.datetime(2017, 4, 30, 4, 0), 5581273],
#    [datetime.datetime(2017, 4, 30, 8, 0), 5581282],
#    [datetime.datetime(2017, 4, 30, 12, 0), 5581337],
#    [datetime.datetime(2017, 4, 30, 16, 0), 5581572],
#    [datetime.datetime(2017, 4, 30, 20, 0), 5581770],
#    [datetime.datetime(2017, 5, 1, 0, 0), 5581851],
#    [datetime.datetime(2017, 5, 1, 4, 0), 5581856],
#    [datetime.datetime(2017, 5, 1, 8, 0), 5581885],
#    [datetime.datetime(2017, 5, 1, 12, 0), 5582005],
#    [datetime.datetime(2017, 5, 1, 16, 0), 5582221],
#    [datetime.datetime(2017, 5, 1, 20, 0), 5582827],
#    [datetime.datetime(2017, 5, 2, 0, 0), 5583047],
#    [datetime.datetime(2017, 5, 2, 4, 0), 5583057],
#    [datetime.datetime(2017, 5, 2, 8, 0), 5583092],
#    [datetime.datetime(2017, 5, 2, 12, 0), 5583220],
#    [datetime.datetime(2017, 5, 2, 16, 0), 5583458],
#    [datetime.datetime(2017, 5, 2, 20, 0), 5584058],
#    [datetime.datetime(2017, 5, 3, 0, 0), 5584235],
#    [datetime.datetime(2017, 5, 3, 4, 0), 5584246],
#    [datetime.datetime(2017, 5, 3, 8, 0), 5584271],
#    [datetime.datetime(2017, 5, 3, 12, 0), 5584402],
#    [datetime.datetime(2017, 5, 3, 16, 0), 5584655],
#    [datetime.datetime(2017, 5, 3, 20, 0), 5585330],
#    [datetime.datetime(2017, 5, 4, 0, 0), 5585515],
#    [datetime.datetime(2017, 5, 4, 4, 0), 5585523],
#    [datetime.datetime(2017, 5, 4, 8, 0), 5585553],
#    [datetime.datetime(2017, 5, 4, 12, 0), 5585680],
#    [datetime.datetime(2017, 5, 4, 16, 0), 5585926],
#    [datetime.datetime(2017, 5, 4, 20, 0), 5586565],
#    [datetime.datetime(2017, 5, 5, 0, 0), 5586785],
#    [datetime.datetime(2017, 5, 5, 4, 0), 5586799],
#    [datetime.datetime(2017, 5, 5, 8, 0), 5586824],
#    [datetime.datetime(2017, 5, 5, 12, 0), 5586962],
#    [datetime.datetime(2017, 5, 5, 16, 0), 5587071],
#    [datetime.datetime(2017, 5, 5, 20, 0), 5587654]]),
#  (('A002', 'R051', '02-03-00', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 904498],
#    [datetime.datetime(2017, 4, 29, 4, 0), 904517],
#    [datetime.datetime(2017, 4, 29, 8, 0), 904535],
#    [datetime.datetime(2017, 4, 29, 12, 0), 904636],
#    [datetime.datetime(2017, 4, 29, 16, 0), 904728],
#    [datetime.datetime(2017, 4, 29, 20, 0), 904868],
#    [datetime.datetime(2017, 4, 30, 0, 0), 904984],
#    [datetime.datetime(2017, 4, 30, 4, 0), 904998],
#    [datetime.datetime(2017, 4, 30, 8, 0), 905002],
#    [datetime.datetime(2017, 4, 30, 12, 0), 905028],
#    [datetime.datetime(2017, 4, 30, 16, 0), 905105],
#    [datetime.datetime(2017, 4, 30, 20, 0), 905198],
#    [datetime.datetime(2017, 5, 1, 0, 0), 905250],
#    [datetime.datetime(2017, 5, 1, 4, 0), 905254],
#    [datetime.datetime(2017, 5, 1, 8, 0), 905275],
#    [datetime.datetime(2017, 5, 1, 12, 0), 905336],
#    [datetime.datetime(2017, 5, 1, 16, 0), 905443],
#    [datetime.datetime(2017, 5, 1, 20, 0), 905756],
#    [datetime.datetime(2017, 5, 2, 0, 0), 905878],
#    [datetime.datetime(2017, 5, 2, 4, 0), 905888],
#    [datetime.datetime(2017, 5, 2, 8, 0), 905903],
#    [datetime.datetime(2017, 5, 2, 12, 0), 905960],
#    [datetime.datetime(2017, 5, 2, 16, 0), 906074],
#    [datetime.datetime(2017, 5, 2, 20, 0), 906344],
#    [datetime.datetime(2017, 5, 3, 0, 0), 906447],
#    [datetime.datetime(2017, 5, 3, 4, 0), 906453],
#    [datetime.datetime(2017, 5, 3, 8, 0), 906471],
#    [datetime.datetime(2017, 5, 3, 12, 0), 906524],
#    [datetime.datetime(2017, 5, 3, 16, 0), 906647],
#    [datetime.datetime(2017, 5, 3, 20, 0), 906964],
#    [datetime.datetime(2017, 5, 4, 0, 0), 907073],
#    [datetime.datetime(2017, 5, 4, 4, 0), 907079],
#    [datetime.datetime(2017, 5, 4, 8, 0), 907098],
#    [datetime.datetime(2017, 5, 4, 12, 0), 907161],
#    [datetime.datetime(2017, 5, 4, 16, 0), 907277],
#    [datetime.datetime(2017, 5, 4, 20, 0), 907569],
#    [datetime.datetime(2017, 5, 5, 0, 0), 907674],
#    [datetime.datetime(2017, 5, 5, 4, 0), 907682],
#    [datetime.datetime(2017, 5, 5, 8, 0), 907699],
#    [datetime.datetime(2017, 5, 5, 12, 0), 907748],
#    [datetime.datetime(2017, 5, 5, 16, 0), 907799],
#    [datetime.datetime(2017, 5, 5, 20, 0), 908037]]),
#  (('A002', 'R051', '02-03-01', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 264039],
#    [datetime.datetime(2017, 4, 29, 4, 0), 264105],
#    [datetime.datetime(2017, 4, 29, 8, 0), 264158],
#    [datetime.datetime(2017, 4, 29, 12, 0), 264376],
#    [datetime.datetime(2017, 4, 29, 16, 0), 264656],
#    [datetime.datetime(2017, 4, 29, 20, 0), 264980],
#    [datetime.datetime(2017, 4, 30, 0, 0), 265191],
#    [datetime.datetime(2017, 4, 30, 4, 0), 265237],
#    [datetime.datetime(2017, 4, 30, 8, 0), 265249],
#    [datetime.datetime(2017, 4, 30, 12, 0), 265350],
#    [datetime.datetime(2017, 4, 30, 16, 0), 265540],
#    [datetime.datetime(2017, 4, 30, 20, 0), 265782],
#    [datetime.datetime(2017, 5, 1, 0, 0), 265955],
#    [datetime.datetime(2017, 5, 1, 4, 0), 265975],
#    [datetime.datetime(2017, 5, 1, 8, 0), 266004],
#    [datetime.datetime(2017, 5, 1, 12, 0), 266167],
#    [datetime.datetime(2017, 5, 1, 16, 0), 266441],
#    [datetime.datetime(2017, 5, 1, 20, 0), 266992],
#    [datetime.datetime(2017, 5, 2, 0, 0), 267199],
#    [datetime.datetime(2017, 5, 2, 4, 0), 267219],
#    [datetime.datetime(2017, 5, 2, 8, 0), 267274],
#    [datetime.datetime(2017, 5, 2, 12, 0), 267444],
#    [datetime.datetime(2017, 5, 2, 16, 0), 267775],
#    [datetime.datetime(2017, 5, 2, 20, 0), 268381],
#    [datetime.datetime(2017, 5, 3, 0, 0), 268663],
#    [datetime.datetime(2017, 5, 3, 4, 0), 268688],
#    [datetime.datetime(2017, 5, 3, 8, 0), 268738],
#    [datetime.datetime(2017, 5, 3, 12, 0), 268913],
#    [datetime.datetime(2017, 5, 3, 16, 0), 269218],
#    [datetime.datetime(2017, 5, 3, 20, 0), 269875],
#    [datetime.datetime(2017, 5, 4, 0, 0), 270155],
#    [datetime.datetime(2017, 5, 4, 4, 0), 270182],
#    [datetime.datetime(2017, 5, 4, 8, 0), 270226],
#    [datetime.datetime(2017, 5, 4, 12, 0), 270371],
#    [datetime.datetime(2017, 5, 4, 16, 0), 270645],
#    [datetime.datetime(2017, 5, 4, 20, 0), 271262],
#    [datetime.datetime(2017, 5, 5, 0, 0), 271551],
#    [datetime.datetime(2017, 5, 5, 4, 0), 271575],
#    [datetime.datetime(2017, 5, 5, 8, 0), 271618],
#    [datetime.datetime(2017, 5, 5, 12, 0), 271771],
#    [datetime.datetime(2017, 5, 5, 16, 0), 271919],
#    [datetime.datetime(2017, 5, 5, 20, 0), 272463]]),
#  (('A002', 'R051', '02-03-02', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 5351047],
#    [datetime.datetime(2017, 4, 29, 4, 0), 5351095],
#    [datetime.datetime(2017, 4, 29, 8, 0), 5351136],
#    [datetime.datetime(2017, 4, 29, 12, 0), 5351316],
#    [datetime.datetime(2017, 4, 29, 16, 0), 5351590],
#    [datetime.datetime(2017, 4, 29, 20, 0), 5351871],
#    [datetime.datetime(2017, 4, 30, 0, 0), 5352096],
#    [datetime.datetime(2017, 4, 30, 4, 0), 5352136],
#    [datetime.datetime(2017, 4, 30, 8, 0), 5352151],
#    [datetime.datetime(2017, 4, 30, 12, 0), 5352227],
#    [datetime.datetime(2017, 4, 30, 16, 0), 5352400],
#    [datetime.datetime(2017, 4, 30, 20, 0), 5352619],
#    [datetime.datetime(2017, 5, 1, 0, 0), 5352740],
#    [datetime.datetime(2017, 5, 1, 4, 0), 5352756],
#    [datetime.datetime(2017, 5, 1, 8, 0), 5352795],
#    [datetime.datetime(2017, 5, 1, 12, 0), 5352990],
#    [datetime.datetime(2017, 5, 1, 16, 0), 5353284],
#    [datetime.datetime(2017, 5, 1, 20, 0), 5353872],
#    [datetime.datetime(2017, 5, 2, 0, 0), 5354016],
#    [datetime.datetime(2017, 5, 2, 4, 0), 5354034],
#    [datetime.datetime(2017, 5, 2, 8, 0), 5354073],
#    [datetime.datetime(2017, 5, 2, 12, 0), 5354246],
#    [datetime.datetime(2017, 5, 2, 16, 0), 5354565],
#    [datetime.datetime(2017, 5, 2, 20, 0), 5355201],
#    [datetime.datetime(2017, 5, 3, 0, 0), 5355434],
#    [datetime.datetime(2017, 5, 3, 4, 0), 5355454],
#    [datetime.datetime(2017, 5, 3, 8, 0), 5355512],
#    [datetime.datetime(2017, 5, 3, 12, 0), 5355705],
#    [datetime.datetime(2017, 5, 3, 16, 0), 5356004],
#    [datetime.datetime(2017, 5, 3, 20, 0), 5356649],
#    [datetime.datetime(2017, 5, 4, 0, 0), 5356893],
#    [datetime.datetime(2017, 5, 4, 4, 0), 5356916],
#    [datetime.datetime(2017, 5, 4, 8, 0), 5356953],
#    [datetime.datetime(2017, 5, 4, 12, 0), 5357127],
#    [datetime.datetime(2017, 5, 4, 16, 0), 5357447],
#    [datetime.datetime(2017, 5, 4, 20, 0), 5358090],
#    [datetime.datetime(2017, 5, 5, 0, 0), 5358336],
#    [datetime.datetime(2017, 5, 5, 4, 0), 5358359],
#    [datetime.datetime(2017, 5, 5, 8, 0), 5358402],
#    [datetime.datetime(2017, 5, 5, 12, 0), 5358585],
#    [datetime.datetime(2017, 5, 5, 16, 0), 5358731],
#    [datetime.datetime(2017, 5, 5, 20, 0), 5359281]])]

# %% [markdown]
# ## Exercise 3
# - These counts are cumulative every n hours. We want total daily entries.
#
# Now make it that we again have the same keys, but now we have a single value for a single day, which is not cumulative counts but the total number of passengers that entered through this turnstile on this day.

# %%
def combine_weeks(weekly_dicts):
    combined = defaultdict(list)
    
    for week in weekly_dicts:
        for turnstile, time_series in week.items():
            combined[turnstile] += time_series
            
    return combined

# %%
combined_time_series = combine_weeks(weekly_time_series)

# %%
list(combined_time_series.items())[:5]
# Out:
# [(('A002', 'R051', '02-00-00', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 6157740],
#    [datetime.datetime(2017, 4, 29, 4, 0), 6157777],
#    [datetime.datetime(2017, 4, 29, 8, 0), 6157810],
#    [datetime.datetime(2017, 4, 29, 12, 0), 6157963],
#    [datetime.datetime(2017, 4, 29, 16, 0), 6158212],
#    [datetime.datetime(2017, 4, 29, 20, 0), 6158521],
#    [datetime.datetime(2017, 4, 30, 0, 0), 6158637],
#    [datetime.datetime(2017, 4, 30, 4, 0), 6158654],
#    [datetime.datetime(2017, 4, 30, 8, 0), 6158661],
#    [datetime.datetime(2017, 4, 30, 12, 0), 6158703],
#    [datetime.datetime(2017, 4, 30, 16, 0), 6158797],
#    [datetime.datetime(2017, 4, 30, 20, 0), 6159015],
#    [datetime.datetime(2017, 5, 1, 0, 0), 6159107],
#    [datetime.datetime(2017, 5, 1, 4, 0), 6159116],
#    [datetime.datetime(2017, 5, 1, 8, 0), 6159166],
#    [datetime.datetime(2017, 5, 1, 12, 0), 6159331],
#    [datetime.datetime(2017, 5, 1, 16, 0), 6159595],
#    [datetime.datetime(2017, 5, 1, 20, 0), 6160374],
#    [datetime.datetime(2017, 5, 2, 0, 0), 6160508],
#    [datetime.datetime(2017, 5, 2, 4, 0), 6160514],
#    [datetime.datetime(2017, 5, 2, 8, 0), 6160555],
#    [datetime.datetime(2017, 5, 2, 12, 0), 6160711],
#    [datetime.datetime(2017, 5, 2, 16, 0), 6161012],
#    [datetime.datetime(2017, 5, 2, 20, 0), 6161830],
#    [datetime.datetime(2017, 5, 3, 0, 0), 6162061],
#    [datetime.datetime(2017, 5, 3, 4, 0), 6162082],
#    [datetime.datetime(2017, 5, 3, 8, 0), 6162129],
#    [datetime.datetime(2017, 5, 3, 12, 0), 6162287],
#    [datetime.datetime(2017, 5, 3, 16, 0), 6162575],
#    [datetime.datetime(2017, 5, 3, 20, 0), 6163254],
#    [datetime.datetime(2017, 5, 4, 0, 0), 6163517],
#    [datetime.datetime(2017, 5, 4, 4, 0), 6163534],
#    [datetime.datetime(2017, 5, 4, 8, 0), 6163576],
#    [datetime.datetime(2017, 5, 4, 12, 0), 6163739],
#    [datetime.datetime(2017, 5, 4, 16, 0), 6164051],
#    [datetime.datetime(2017, 5, 4, 20, 0), 6164865],
#    [datetime.datetime(2017, 5, 5, 0, 0), 6165120],
#    [datetime.datetime(2017, 5, 5, 4, 0), 6165147],
#    [datetime.datetime(2017, 5, 5, 8, 0), 6165183],
#    [datetime.datetime(2017, 5, 5, 12, 0), 6165346],
#    [datetime.datetime(2017, 5, 5, 16, 0), 6165481],
#    [datetime.datetime(2017, 5, 5, 20, 0), 6166192],
#    [datetime.datetime(2017, 5, 6, 0, 0), 6166390],
#    [datetime.datetime(2017, 5, 6, 4, 0), 6166420],
#    [datetime.datetime(2017, 5, 6, 8, 0), 6166433],
#    [datetime.datetime(2017, 5, 6, 12, 0), 6166514],
#    [datetime.datetime(2017, 5, 6, 16, 0), 6166791],
#    [datetime.datetime(2017, 5, 6, 20, 0), 6167090],
#    [datetime.datetime(2017, 5, 7, 0, 0), 6167259],
#    [datetime.datetime(2017, 5, 7, 4, 0), 6167284],
#    [datetime.datetime(2017, 5, 7, 8, 0), 6167297],
#    [datetime.datetime(2017, 5, 7, 12, 0), 6167402],
#    [datetime.datetime(2017, 5, 7, 16, 0), 6167605],
#    [datetime.datetime(2017, 5, 7, 20, 0), 6167857],
#    [datetime.datetime(2017, 5, 8, 0, 0), 6167955],
#    [datetime.datetime(2017, 5, 8, 4, 0), 6167963],
#    [datetime.datetime(2017, 5, 8, 8, 0), 6168003],
#    [datetime.datetime(2017, 5, 8, 12, 0), 6168197],
#    [datetime.datetime(2017, 5, 8, 16, 0), 6168523],
#    [datetime.datetime(2017, 5, 8, 20, 0), 6169303],
#    [datetime.datetime(2017, 5, 9, 0, 0), 6169536],
#    [datetime.datetime(2017, 5, 9, 4, 0), 6169566],
#    [datetime.datetime(2017, 5, 9, 8, 0), 6169600],
#    [datetime.datetime(2017, 5, 9, 12, 0), 6169748],
#    [datetime.datetime(2017, 5, 9, 16, 0), 6170086],
#    [datetime.datetime(2017, 5, 9, 20, 0), 6170839],
#    [datetime.datetime(2017, 5, 10, 0, 0), 6171059],
#    [datetime.datetime(2017, 5, 10, 4, 0), 6171075],
#    [datetime.datetime(2017, 5, 10, 8, 0), 6171120],
#    [datetime.datetime(2017, 5, 10, 12, 0), 6171297],
#    [datetime.datetime(2017, 5, 10, 16, 0), 6171646],
#    [datetime.datetime(2017, 5, 10, 20, 0), 6172382],
#    [datetime.datetime(2017, 5, 11, 0, 0), 6172600],
#    [datetime.datetime(2017, 5, 11, 4, 0), 6172626],
#    [datetime.datetime(2017, 5, 11, 8, 0), 6172674],
#    [datetime.datetime(2017, 5, 11, 12, 0), 6172862],
#    [datetime.datetime(2017, 5, 11, 16, 0), 6173173],
#    [datetime.datetime(2017, 5, 11, 20, 0), 6173936],
#    [datetime.datetime(2017, 5, 12, 0, 0), 6174189],
#    [datetime.datetime(2017, 5, 12, 4, 0), 6174210],
#    [datetime.datetime(2017, 5, 12, 8, 0), 6174252],
#    [datetime.datetime(2017, 5, 12, 12, 0), 6174424],
#    [datetime.datetime(2017, 5, 12, 16, 0), 6174767],
#    [datetime.datetime(2017, 5, 12, 20, 0), 6175691],
#    [datetime.datetime(2017, 5, 13, 0, 0), 6175956],
#    [datetime.datetime(2017, 5, 13, 4, 0), 6176001],
#    [datetime.datetime(2017, 5, 13, 8, 0), 6176032],
#    [datetime.datetime(2017, 5, 13, 12, 0), 6176121],
#    [datetime.datetime(2017, 5, 13, 16, 0), 6176394],
#    [datetime.datetime(2017, 5, 13, 20, 0), 6176686],
#    [datetime.datetime(2017, 5, 14, 0, 0), 6176825],
#    [datetime.datetime(2017, 5, 14, 4, 0), 6176848],
#    [datetime.datetime(2017, 5, 14, 8, 0), 6176865],
#    [datetime.datetime(2017, 5, 14, 12, 0), 6177004],
#    [datetime.datetime(2017, 5, 14, 16, 0), 6177244],
#    [datetime.datetime(2017, 5, 14, 20, 0), 6177535],
#    [datetime.datetime(2017, 5, 15, 0, 0), 6177671],
#    [datetime.datetime(2017, 5, 15, 4, 0), 6177681],
#    [datetime.datetime(2017, 5, 15, 8, 0), 6177725],
#    [datetime.datetime(2017, 5, 15, 12, 0), 6177927],
#    [datetime.datetime(2017, 5, 15, 16, 0), 6178313],
#    [datetime.datetime(2017, 5, 15, 20, 0), 6179092],
#    [datetime.datetime(2017, 5, 16, 0, 0), 6179262],
#    [datetime.datetime(2017, 5, 16, 4, 0), 6179279],
#    [datetime.datetime(2017, 5, 16, 8, 0), 6179325],
#    [datetime.datetime(2017, 5, 16, 12, 0), 6179434],
#    [datetime.datetime(2017, 5, 16, 16, 0), 6179666],
#    [datetime.datetime(2017, 5, 16, 20, 0), 6180099],
#    [datetime.datetime(2017, 5, 17, 0, 0), 6180269],
#    [datetime.datetime(2017, 5, 17, 4, 0), 6180270],
#    [datetime.datetime(2017, 5, 17, 8, 0), 6180312],
#    [datetime.datetime(2017, 5, 17, 12, 0), 6180472],
#    [datetime.datetime(2017, 5, 17, 16, 0), 6180760],
#    [datetime.datetime(2017, 5, 17, 20, 0), 6181544],
#    [datetime.datetime(2017, 5, 18, 0, 0), 6181793],
#    [datetime.datetime(2017, 5, 18, 4, 0), 6181800],
#    [datetime.datetime(2017, 5, 18, 8, 0), 6181849],
#    [datetime.datetime(2017, 5, 18, 12, 0), 6182017],
#    [datetime.datetime(2017, 5, 18, 16, 0), 6182334],
#    [datetime.datetime(2017, 5, 18, 20, 0), 6183046],
#    [datetime.datetime(2017, 5, 19, 0, 0), 6183294],
#    [datetime.datetime(2017, 5, 19, 4, 0), 6183295],
#    [datetime.datetime(2017, 5, 19, 8, 0), 6183333],
#    [datetime.datetime(2017, 5, 19, 12, 0), 6183506],
#    [datetime.datetime(2017, 5, 19, 16, 0), 6183861],
#    [datetime.datetime(2017, 5, 19, 20, 0), 6184615],
#    [datetime.datetime(2017, 5, 20, 0, 0), 6184841],
#    [datetime.datetime(2017, 5, 20, 4, 0), 6184865],
#    [datetime.datetime(2017, 5, 20, 8, 0), 6184891],
#    [datetime.datetime(2017, 5, 20, 12, 0), 6184973],
#    [datetime.datetime(2017, 5, 20, 16, 0), 6185217],
#    [datetime.datetime(2017, 5, 20, 20, 0), 6185506],
#    [datetime.datetime(2017, 5, 21, 0, 0), 6185634],
#    [datetime.datetime(2017, 5, 21, 4, 0), 6185655],
#    [datetime.datetime(2017, 5, 21, 8, 0), 6185665],
#    [datetime.datetime(2017, 5, 21, 12, 0), 6185734],
#    [datetime.datetime(2017, 5, 21, 16, 0), 6185889],
#    [datetime.datetime(2017, 5, 21, 20, 0), 6186111],
#    [datetime.datetime(2017, 5, 22, 0, 0), 6186215],
#    [datetime.datetime(2017, 5, 22, 8, 0), 6186282],
#    [datetime.datetime(2017, 5, 22, 12, 0), 6186432],
#    [datetime.datetime(2017, 5, 22, 16, 0), 6186689],
#    [datetime.datetime(2017, 5, 22, 20, 0), 6187464],
#    [datetime.datetime(2017, 5, 23, 0, 0), 6187676],
#    [datetime.datetime(2017, 5, 23, 4, 0), 6187697],
#    [datetime.datetime(2017, 5, 23, 8, 0), 6187746],
#    [datetime.datetime(2017, 5, 23, 12, 0), 6187922],
#    [datetime.datetime(2017, 5, 23, 16, 0), 6188310],
#    [datetime.datetime(2017, 5, 23, 20, 0), 6189254],
#    [datetime.datetime(2017, 5, 24, 0, 0), 6189483],
#    [datetime.datetime(2017, 5, 24, 4, 0), 6189502],
#    [datetime.datetime(2017, 5, 24, 8, 0), 6189551],
#    [datetime.datetime(2017, 5, 24, 12, 0), 6189812],
#    [datetime.datetime(2017, 5, 24, 16, 0), 6190313],
#    [datetime.datetime(2017, 5, 24, 20, 0), 6191210],
#    [datetime.datetime(2017, 5, 25, 0, 0), 6191488],
#    [datetime.datetime(2017, 5, 25, 4, 0), 6191496],
#    [datetime.datetime(2017, 5, 25, 8, 0), 6191554],
#    [datetime.datetime(2017, 5, 25, 12, 0), 6191777],
#    [datetime.datetime(2017, 5, 25, 16, 0), 6192264],
#    [datetime.datetime(2017, 5, 25, 20, 0), 6193276],
#    [datetime.datetime(2017, 5, 26, 0, 0), 6193582],
#    [datetime.datetime(2017, 5, 26, 4, 0), 6193605],
#    [datetime.datetime(2017, 5, 26, 8, 0), 6193662],
#    [datetime.datetime(2017, 5, 26, 12, 0), 6193864],
#    [datetime.datetime(2017, 5, 26, 16, 0), 6194321],
#    [datetime.datetime(2017, 5, 26, 20, 0), 6194995]]),
#  (('A002', 'R051', '02-00-01', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 5580416],
#    [datetime.datetime(2017, 4, 29, 4, 0), 5580437],
#    [datetime.datetime(2017, 4, 29, 8, 0), 5580462],
#    [datetime.datetime(2017, 4, 29, 12, 0), 5580581],
#    [datetime.datetime(2017, 4, 29, 16, 0), 5580766],
#    [datetime.datetime(2017, 4, 29, 20, 0), 5581062],
#    [datetime.datetime(2017, 4, 30, 0, 0), 5581232],
#    [datetime.datetime(2017, 4, 30, 4, 0), 5581273],
#    [datetime.datetime(2017, 4, 30, 8, 0), 5581282],
#    [datetime.datetime(2017, 4, 30, 12, 0), 5581337],
#    [datetime.datetime(2017, 4, 30, 16, 0), 5581572],
#    [datetime.datetime(2017, 4, 30, 20, 0), 5581770],
#    [datetime.datetime(2017, 5, 1, 0, 0), 5581851],
#    [datetime.datetime(2017, 5, 1, 4, 0), 5581856],
#    [datetime.datetime(2017, 5, 1, 8, 0), 5581885],
#    [datetime.datetime(2017, 5, 1, 12, 0), 5582005],
#    [datetime.datetime(2017, 5, 1, 16, 0), 5582221],
#    [datetime.datetime(2017, 5, 1, 20, 0), 5582827],
#    [datetime.datetime(2017, 5, 2, 0, 0), 5583047],
#    [datetime.datetime(2017, 5, 2, 4, 0), 5583057],
#    [datetime.datetime(2017, 5, 2, 8, 0), 5583092],
#    [datetime.datetime(2017, 5, 2, 12, 0), 5583220],
#    [datetime.datetime(2017, 5, 2, 16, 0), 5583458],
#    [datetime.datetime(2017, 5, 2, 20, 0), 5584058],
#    [datetime.datetime(2017, 5, 3, 0, 0), 5584235],
#    [datetime.datetime(2017, 5, 3, 4, 0), 5584246],
#    [datetime.datetime(2017, 5, 3, 8, 0), 5584271],
#    [datetime.datetime(2017, 5, 3, 12, 0), 5584402],
#    [datetime.datetime(2017, 5, 3, 16, 0), 5584655],
#    [datetime.datetime(2017, 5, 3, 20, 0), 5585330],
#    [datetime.datetime(2017, 5, 4, 0, 0), 5585515],
#    [datetime.datetime(2017, 5, 4, 4, 0), 5585523],
#    [datetime.datetime(2017, 5, 4, 8, 0), 5585553],
#    [datetime.datetime(2017, 5, 4, 12, 0), 5585680],
#    [datetime.datetime(2017, 5, 4, 16, 0), 5585926],
#    [datetime.datetime(2017, 5, 4, 20, 0), 5586565],
#    [datetime.datetime(2017, 5, 5, 0, 0), 5586785],
#    [datetime.datetime(2017, 5, 5, 4, 0), 5586799],
#    [datetime.datetime(2017, 5, 5, 8, 0), 5586824],
#    [datetime.datetime(2017, 5, 5, 12, 0), 5586962],
#    [datetime.datetime(2017, 5, 5, 16, 0), 5587071],
#    [datetime.datetime(2017, 5, 5, 20, 0), 5587654],
#    [datetime.datetime(2017, 5, 6, 0, 0), 5587839],
#    [datetime.datetime(2017, 5, 6, 4, 0), 5587852],
#    [datetime.datetime(2017, 5, 6, 8, 0), 5587861],
#    [datetime.datetime(2017, 5, 6, 12, 0), 5587927],
#    [datetime.datetime(2017, 5, 6, 16, 0), 5588072],
#    [datetime.datetime(2017, 5, 6, 20, 0), 5588336],
#    [datetime.datetime(2017, 5, 7, 0, 0), 5588457],
#    [datetime.datetime(2017, 5, 7, 4, 0), 5588473],
#    [datetime.datetime(2017, 5, 7, 8, 0), 5588480],
#    [datetime.datetime(2017, 5, 7, 12, 0), 5588538],
#    [datetime.datetime(2017, 5, 7, 16, 0), 5588680],
#    [datetime.datetime(2017, 5, 7, 20, 0), 5588846],
#    [datetime.datetime(2017, 5, 8, 0, 0), 5588927],
#    [datetime.datetime(2017, 5, 8, 4, 0), 5588931],
#    [datetime.datetime(2017, 5, 8, 8, 0), 5588951],
#    [datetime.datetime(2017, 5, 8, 12, 0), 5589069],
#    [datetime.datetime(2017, 5, 8, 16, 0), 5589223],
#    [datetime.datetime(2017, 5, 8, 20, 0), 5589835],
#    [datetime.datetime(2017, 5, 9, 0, 0), 5590002],
#    [datetime.datetime(2017, 5, 9, 4, 0), 5590010],
#    [datetime.datetime(2017, 5, 9, 8, 0), 5590041],
#    [datetime.datetime(2017, 5, 9, 12, 0), 5590183],
#    [datetime.datetime(2017, 5, 9, 16, 0), 5590428],
#    [datetime.datetime(2017, 5, 9, 20, 0), 5591009],
#    [datetime.datetime(2017, 5, 10, 0, 0), 5591142],
#    [datetime.datetime(2017, 5, 10, 4, 0), 5591147],
#    [datetime.datetime(2017, 5, 10, 8, 0), 5591172],
#    [datetime.datetime(2017, 5, 10, 12, 0), 5591298],
#    [datetime.datetime(2017, 5, 10, 16, 0), 5591543],
#    [datetime.datetime(2017, 5, 10, 20, 0), 5592064],
#    [datetime.datetime(2017, 5, 11, 0, 0), 5592255],
#    [datetime.datetime(2017, 5, 11, 4, 0), 5592270],
#    [datetime.datetime(2017, 5, 11, 8, 0), 5592310],
#    [datetime.datetime(2017, 5, 11, 12, 0), 5592426],
#    [datetime.datetime(2017, 5, 11, 16, 0), 5592654],
#    [datetime.datetime(2017, 5, 11, 20, 0), 5593271],
#    [datetime.datetime(2017, 5, 12, 0, 0), 5593449],
#    [datetime.datetime(2017, 5, 12, 4, 0), 5593464],
#    [datetime.datetime(2017, 5, 12, 8, 0), 5593486],
#    [datetime.datetime(2017, 5, 12, 12, 0), 5593632],
#    [datetime.datetime(2017, 5, 12, 16, 0), 5593889],
#    [datetime.datetime(2017, 5, 12, 20, 0), 5594156],
#    [datetime.datetime(2017, 5, 13, 0, 0), 5594253],
#    [datetime.datetime(2017, 5, 13, 4, 0), 5594259],
#    [datetime.datetime(2017, 5, 13, 8, 0), 5594261],
#    [datetime.datetime(2017, 5, 13, 12, 0), 5594313],
#    [datetime.datetime(2017, 5, 13, 16, 0), 5594379],
#    [datetime.datetime(2017, 5, 13, 20, 0), 5594478],
#    [datetime.datetime(2017, 5, 14, 0, 0), 5594521],
#    [datetime.datetime(2017, 5, 14, 4, 0), 5594527],
#    [datetime.datetime(2017, 5, 14, 8, 0), 5594528],
#    [datetime.datetime(2017, 5, 14, 12, 0), 5594559],
#    [datetime.datetime(2017, 5, 14, 16, 0), 5594637],
#    [datetime.datetime(2017, 5, 14, 20, 0), 5594747],
#    [datetime.datetime(2017, 5, 15, 0, 0), 5594762],
#    [datetime.datetime(2017, 5, 15, 4, 0), 5594765],
#    [datetime.datetime(2017, 5, 15, 8, 0), 5594772],
#    [datetime.datetime(2017, 5, 15, 12, 0), 5594813],
#    [datetime.datetime(2017, 5, 15, 16, 0), 5594945],
#    [datetime.datetime(2017, 5, 15, 20, 0), 5595539],
#    [datetime.datetime(2017, 5, 16, 0, 0), 5595704],
#    [datetime.datetime(2017, 5, 16, 4, 0), 5595716],
#    [datetime.datetime(2017, 5, 16, 8, 0), 5595743],
#    [datetime.datetime(2017, 5, 16, 12, 0), 5595903],
#    [datetime.datetime(2017, 5, 16, 16, 0), 5596167],
#    [datetime.datetime(2017, 5, 16, 20, 0), 5596936],
#    [datetime.datetime(2017, 5, 17, 0, 0), 5597129],
#    [datetime.datetime(2017, 5, 17, 4, 0), 5597129],
#    [datetime.datetime(2017, 5, 17, 8, 0), 5597154],
#    [datetime.datetime(2017, 5, 17, 12, 0), 5597265],
#    [datetime.datetime(2017, 5, 17, 16, 0), 5597493],
#    [datetime.datetime(2017, 5, 17, 20, 0), 5598088],
#    [datetime.datetime(2017, 5, 18, 0, 0), 5598270],
#    [datetime.datetime(2017, 5, 18, 4, 0), 5598272],
#    [datetime.datetime(2017, 5, 18, 8, 0), 5598302],
#    [datetime.datetime(2017, 5, 18, 12, 0), 5598434],
#    [datetime.datetime(2017, 5, 18, 16, 0), 5598693],
#    [datetime.datetime(2017, 5, 18, 20, 0), 5599318],
#    [datetime.datetime(2017, 5, 19, 0, 0), 5599494],
#    [datetime.datetime(2017, 5, 19, 4, 0), 5599497],
#    [datetime.datetime(2017, 5, 19, 8, 0), 5599516],
#    [datetime.datetime(2017, 5, 19, 12, 0), 5599669],
#    [datetime.datetime(2017, 5, 19, 16, 0), 5599912],
#    [datetime.datetime(2017, 5, 19, 20, 0), 5600526],
#    [datetime.datetime(2017, 5, 20, 0, 0), 5600700],
#    [datetime.datetime(2017, 5, 20, 4, 0), 5600713],
#    [datetime.datetime(2017, 5, 20, 8, 0), 5600725],
#    [datetime.datetime(2017, 5, 20, 12, 0), 5600778],
#    [datetime.datetime(2017, 5, 20, 16, 0), 5600971],
#    [datetime.datetime(2017, 5, 20, 20, 0), 5601237],
#    [datetime.datetime(2017, 5, 21, 0, 0), 5601355],
#    [datetime.datetime(2017, 5, 21, 4, 0), 5601378],
#    [datetime.datetime(2017, 5, 21, 8, 0), 5601390],
#    [datetime.datetime(2017, 5, 21, 12, 0), 5601458],
#    [datetime.datetime(2017, 5, 21, 16, 0), 5601608],
#    [datetime.datetime(2017, 5, 21, 20, 0), 5601799],
#    [datetime.datetime(2017, 5, 22, 0, 0), 5601882],
#    [datetime.datetime(2017, 5, 22, 8, 0), 5601915],
#    [datetime.datetime(2017, 5, 22, 12, 0), 5602053],
#    [datetime.datetime(2017, 5, 22, 16, 0), 5602262],
#    [datetime.datetime(2017, 5, 22, 20, 0), 5602825],
#    [datetime.datetime(2017, 5, 23, 0, 0), 5602965],
#    [datetime.datetime(2017, 5, 23, 4, 0), 5602971],
#    [datetime.datetime(2017, 5, 23, 8, 0), 5602997],
#    [datetime.datetime(2017, 5, 23, 12, 0), 5603109],
#    [datetime.datetime(2017, 5, 23, 16, 0), 5603212],
#    [datetime.datetime(2017, 5, 23, 20, 0), 5603645],
#    [datetime.datetime(2017, 5, 24, 0, 0), 5603777],
#    [datetime.datetime(2017, 5, 24, 4, 0), 5603777],
#    [datetime.datetime(2017, 5, 24, 8, 0), 5603780],
#    [datetime.datetime(2017, 5, 24, 12, 0), 5603793],
#    [datetime.datetime(2017, 5, 24, 16, 0), 5603837],
#    [datetime.datetime(2017, 5, 24, 20, 0), 5604311],
#    [datetime.datetime(2017, 5, 25, 0, 0), 5604384],
#    [datetime.datetime(2017, 5, 25, 4, 0), 5604392],
#    [datetime.datetime(2017, 5, 25, 8, 0), 5604413],
#    [datetime.datetime(2017, 5, 25, 12, 0), 5604458],
#    [datetime.datetime(2017, 5, 25, 16, 0), 5604488],
#    [datetime.datetime(2017, 5, 25, 20, 0), 5604645],
#    [datetime.datetime(2017, 5, 26, 0, 0), 5604711],
#    [datetime.datetime(2017, 5, 26, 4, 0), 5604719],
#    [datetime.datetime(2017, 5, 26, 8, 0), 5604723],
#    [datetime.datetime(2017, 5, 26, 12, 0), 5604832],
#    [datetime.datetime(2017, 5, 26, 16, 0), 5605188],
#    [datetime.datetime(2017, 5, 26, 20, 0), 5605702]]),
#  (('A002', 'R051', '02-03-00', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 904498],
#    [datetime.datetime(2017, 4, 29, 4, 0), 904517],
#    [datetime.datetime(2017, 4, 29, 8, 0), 904535],
#    [datetime.datetime(2017, 4, 29, 12, 0), 904636],
#    [datetime.datetime(2017, 4, 29, 16, 0), 904728],
#    [datetime.datetime(2017, 4, 29, 20, 0), 904868],
#    [datetime.datetime(2017, 4, 30, 0, 0), 904984],
#    [datetime.datetime(2017, 4, 30, 4, 0), 904998],
#    [datetime.datetime(2017, 4, 30, 8, 0), 905002],
#    [datetime.datetime(2017, 4, 30, 12, 0), 905028],
#    [datetime.datetime(2017, 4, 30, 16, 0), 905105],
#    [datetime.datetime(2017, 4, 30, 20, 0), 905198],
#    [datetime.datetime(2017, 5, 1, 0, 0), 905250],
#    [datetime.datetime(2017, 5, 1, 4, 0), 905254],
#    [datetime.datetime(2017, 5, 1, 8, 0), 905275],
#    [datetime.datetime(2017, 5, 1, 12, 0), 905336],
#    [datetime.datetime(2017, 5, 1, 16, 0), 905443],
#    [datetime.datetime(2017, 5, 1, 20, 0), 905756],
#    [datetime.datetime(2017, 5, 2, 0, 0), 905878],
#    [datetime.datetime(2017, 5, 2, 4, 0), 905888],
#    [datetime.datetime(2017, 5, 2, 8, 0), 905903],
#    [datetime.datetime(2017, 5, 2, 12, 0), 905960],
#    [datetime.datetime(2017, 5, 2, 16, 0), 906074],
#    [datetime.datetime(2017, 5, 2, 20, 0), 906344],
#    [datetime.datetime(2017, 5, 3, 0, 0), 906447],
#    [datetime.datetime(2017, 5, 3, 4, 0), 906453],
#    [datetime.datetime(2017, 5, 3, 8, 0), 906471],
#    [datetime.datetime(2017, 5, 3, 12, 0), 906524],
#    [datetime.datetime(2017, 5, 3, 16, 0), 906647],
#    [datetime.datetime(2017, 5, 3, 20, 0), 906964],
#    [datetime.datetime(2017, 5, 4, 0, 0), 907073],
#    [datetime.datetime(2017, 5, 4, 4, 0), 907079],
#    [datetime.datetime(2017, 5, 4, 8, 0), 907098],
#    [datetime.datetime(2017, 5, 4, 12, 0), 907161],
#    [datetime.datetime(2017, 5, 4, 16, 0), 907277],
#    [datetime.datetime(2017, 5, 4, 20, 0), 907569],
#    [datetime.datetime(2017, 5, 5, 0, 0), 907674],
#    [datetime.datetime(2017, 5, 5, 4, 0), 907682],
#    [datetime.datetime(2017, 5, 5, 8, 0), 907699],
#    [datetime.datetime(2017, 5, 5, 12, 0), 907748],
#    [datetime.datetime(2017, 5, 5, 16, 0), 907799],
#    [datetime.datetime(2017, 5, 5, 20, 0), 908037],
#    [datetime.datetime(2017, 5, 6, 0, 0), 908118],
#    [datetime.datetime(2017, 5, 6, 4, 0), 908129],
#    [datetime.datetime(2017, 5, 6, 8, 0), 908138],
#    [datetime.datetime(2017, 5, 6, 12, 0), 908174],
#    [datetime.datetime(2017, 5, 6, 16, 0), 908257],
#    [datetime.datetime(2017, 5, 6, 20, 0), 908358],
#    [datetime.datetime(2017, 5, 7, 0, 0), 908436],
#    [datetime.datetime(2017, 5, 7, 4, 0), 908443],
#    [datetime.datetime(2017, 5, 7, 8, 0), 908446],
#    [datetime.datetime(2017, 5, 7, 12, 0), 908484],
#    [datetime.datetime(2017, 5, 7, 16, 0), 908557],
#    [datetime.datetime(2017, 5, 7, 20, 0), 908651],
#    [datetime.datetime(2017, 5, 8, 0, 0), 908722],
#    [datetime.datetime(2017, 5, 8, 4, 0), 908727],
#    [datetime.datetime(2017, 5, 8, 8, 0), 908744],
#    [datetime.datetime(2017, 5, 8, 12, 0), 908792],
#    [datetime.datetime(2017, 5, 8, 16, 0), 908919],
#    [datetime.datetime(2017, 5, 8, 20, 0), 909188],
#    [datetime.datetime(2017, 5, 9, 0, 0), 909276],
#    [datetime.datetime(2017, 5, 9, 4, 0), 909280],
#    [datetime.datetime(2017, 5, 9, 8, 0), 909291],
#    [datetime.datetime(2017, 5, 9, 12, 0), 909361],
#    [datetime.datetime(2017, 5, 9, 16, 0), 909493],
#    [datetime.datetime(2017, 5, 9, 20, 0), 909785],
#    [datetime.datetime(2017, 5, 10, 0, 0), 909877],
#    [datetime.datetime(2017, 5, 10, 4, 0), 909883],
#    [datetime.datetime(2017, 5, 10, 8, 0), 909906],
#    [datetime.datetime(2017, 5, 10, 12, 0), 909963],
#    [datetime.datetime(2017, 5, 10, 16, 0), 910065],
#    [datetime.datetime(2017, 5, 10, 20, 0), 910325],
#    [datetime.datetime(2017, 5, 11, 0, 0), 910416],
#    [datetime.datetime(2017, 5, 11, 4, 0), 910422],
#    [datetime.datetime(2017, 5, 11, 8, 0), 910432],
#    [datetime.datetime(2017, 5, 11, 12, 0), 910482],
#    [datetime.datetime(2017, 5, 11, 16, 0), 910566],
#    [datetime.datetime(2017, 5, 11, 20, 0), 910838],
#    [datetime.datetime(2017, 5, 12, 0, 0), 910942],
#    [datetime.datetime(2017, 5, 12, 4, 0), 910951],
#    [datetime.datetime(2017, 5, 12, 8, 0), 910972],
#    [datetime.datetime(2017, 5, 12, 12, 0), 911043],
#    [datetime.datetime(2017, 5, 12, 16, 0), 911143],
#    [datetime.datetime(2017, 5, 12, 20, 0), 911407],
#    [datetime.datetime(2017, 5, 13, 0, 0), 911514],
#    [datetime.datetime(2017, 5, 13, 4, 0), 911524],
#    [datetime.datetime(2017, 5, 13, 8, 0), 911533],
#    [datetime.datetime(2017, 5, 13, 12, 0), 911567],
#    [datetime.datetime(2017, 5, 13, 16, 0), 911660],
#    [datetime.datetime(2017, 5, 13, 20, 0), 911769],
#    [datetime.datetime(2017, 5, 14, 0, 0), 911834],
#    [datetime.datetime(2017, 5, 14, 4, 0), 911839],
#    [datetime.datetime(2017, 5, 14, 8, 0), 911844],
#    [datetime.datetime(2017, 5, 14, 12, 0), 911891],
#    [datetime.datetime(2017, 5, 14, 16, 0), 911951],
#    [datetime.datetime(2017, 5, 14, 20, 0), 912033],
#    [datetime.datetime(2017, 5, 15, 0, 0), 912102],
#    [datetime.datetime(2017, 5, 15, 4, 0), 912103],
#    [datetime.datetime(2017, 5, 15, 8, 0), 912118],
#    [datetime.datetime(2017, 5, 15, 12, 0), 912178],
#    [datetime.datetime(2017, 5, 15, 16, 0), 912305],
#    [datetime.datetime(2017, 5, 15, 20, 0), 912573],
#    [datetime.datetime(2017, 5, 16, 0, 0), 912674],
#    [datetime.datetime(2017, 5, 16, 4, 0), 912680],
#    [datetime.datetime(2017, 5, 16, 8, 0), 912709],
#    [datetime.datetime(2017, 5, 16, 12, 0), 912765],
#    [datetime.datetime(2017, 5, 16, 16, 0), 912874],
#    [datetime.datetime(2017, 5, 16, 20, 0), 913268],
#    [datetime.datetime(2017, 5, 17, 0, 0), 913373],
#    [datetime.datetime(2017, 5, 17, 4, 0), 913373],
#    [datetime.datetime(2017, 5, 17, 8, 0), 913390],
#    [datetime.datetime(2017, 5, 17, 12, 0), 913455],
#    [datetime.datetime(2017, 5, 17, 16, 0), 913581],
#    [datetime.datetime(2017, 5, 17, 20, 0), 913837],
#    [datetime.datetime(2017, 5, 18, 0, 0), 913938],
#    [datetime.datetime(2017, 5, 18, 4, 0), 913938],
#    [datetime.datetime(2017, 5, 18, 8, 0), 913954],
#    [datetime.datetime(2017, 5, 18, 12, 0), 914011],
#    [datetime.datetime(2017, 5, 18, 16, 0), 914129],
#    [datetime.datetime(2017, 5, 18, 20, 0), 914462],
#    [datetime.datetime(2017, 5, 19, 0, 0), 914608],
#    [datetime.datetime(2017, 5, 19, 4, 0), 914608],
#    [datetime.datetime(2017, 5, 19, 8, 0), 914628],
#    [datetime.datetime(2017, 5, 19, 12, 0), 914682],
#    [datetime.datetime(2017, 5, 19, 16, 0), 914764],
#    [datetime.datetime(2017, 5, 19, 20, 0), 914979],
#    [datetime.datetime(2017, 5, 20, 0, 0), 915123],
#    [datetime.datetime(2017, 5, 20, 4, 0), 915132],
#    [datetime.datetime(2017, 5, 20, 8, 0), 915141],
#    [datetime.datetime(2017, 5, 20, 12, 0), 915194],
#    [datetime.datetime(2017, 5, 20, 16, 0), 915297],
#    [datetime.datetime(2017, 5, 20, 20, 0), 915427],
#    [datetime.datetime(2017, 5, 21, 0, 0), 915512],
#    [datetime.datetime(2017, 5, 21, 4, 0), 915525],
#    [datetime.datetime(2017, 5, 21, 8, 0), 915531],
#    [datetime.datetime(2017, 5, 21, 12, 0), 915560],
#    [datetime.datetime(2017, 5, 21, 16, 0), 915619],
#    [datetime.datetime(2017, 5, 21, 20, 0), 915741],
#    [datetime.datetime(2017, 5, 22, 0, 0), 915795],
#    [datetime.datetime(2017, 5, 22, 4, 0), 915797],
#    [datetime.datetime(2017, 5, 22, 8, 0), 915807],
#    [datetime.datetime(2017, 5, 22, 12, 0), 915858],
#    [datetime.datetime(2017, 5, 22, 16, 0), 915959],
#    [datetime.datetime(2017, 5, 22, 20, 0), 916198],
#    [datetime.datetime(2017, 5, 23, 0, 0), 916275],
#    [datetime.datetime(2017, 5, 23, 4, 0), 916281],
#    [datetime.datetime(2017, 5, 23, 8, 0), 916295],
#    [datetime.datetime(2017, 5, 23, 12, 0), 916347],
#    [datetime.datetime(2017, 5, 23, 16, 0), 916489],
#    [datetime.datetime(2017, 5, 23, 20, 0), 916787],
#    [datetime.datetime(2017, 5, 24, 0, 0), 916893],
#    [datetime.datetime(2017, 5, 24, 4, 0), 916909],
#    [datetime.datetime(2017, 5, 24, 8, 0), 916928],
#    [datetime.datetime(2017, 5, 24, 12, 0), 917021],
#    [datetime.datetime(2017, 5, 24, 16, 0), 917168],
#    [datetime.datetime(2017, 5, 24, 20, 0), 917443],
#    [datetime.datetime(2017, 5, 25, 0, 0), 917547],
#    [datetime.datetime(2017, 5, 25, 4, 0), 917555],
#    [datetime.datetime(2017, 5, 25, 8, 0), 917574],
#    [datetime.datetime(2017, 5, 25, 12, 0), 917651],
#    [datetime.datetime(2017, 5, 25, 16, 0), 917807],
#    [datetime.datetime(2017, 5, 25, 20, 0), 918158],
#    [datetime.datetime(2017, 5, 26, 0, 0), 918269],
#    [datetime.datetime(2017, 5, 26, 4, 0), 918273],
#    [datetime.datetime(2017, 5, 26, 8, 0), 918287],
#    [datetime.datetime(2017, 5, 26, 12, 0), 918346],
#    [datetime.datetime(2017, 5, 26, 16, 0), 918528],
#    [datetime.datetime(2017, 5, 26, 20, 0), 918786]]),
#  (('A002', 'R051', '02-03-01', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 264039],
#    [datetime.datetime(2017, 4, 29, 4, 0), 264105],
#    [datetime.datetime(2017, 4, 29, 8, 0), 264158],
#    [datetime.datetime(2017, 4, 29, 12, 0), 264376],
#    [datetime.datetime(2017, 4, 29, 16, 0), 264656],
#    [datetime.datetime(2017, 4, 29, 20, 0), 264980],
#    [datetime.datetime(2017, 4, 30, 0, 0), 265191],
#    [datetime.datetime(2017, 4, 30, 4, 0), 265237],
#    [datetime.datetime(2017, 4, 30, 8, 0), 265249],
#    [datetime.datetime(2017, 4, 30, 12, 0), 265350],
#    [datetime.datetime(2017, 4, 30, 16, 0), 265540],
#    [datetime.datetime(2017, 4, 30, 20, 0), 265782],
#    [datetime.datetime(2017, 5, 1, 0, 0), 265955],
#    [datetime.datetime(2017, 5, 1, 4, 0), 265975],
#    [datetime.datetime(2017, 5, 1, 8, 0), 266004],
#    [datetime.datetime(2017, 5, 1, 12, 0), 266167],
#    [datetime.datetime(2017, 5, 1, 16, 0), 266441],
#    [datetime.datetime(2017, 5, 1, 20, 0), 266992],
#    [datetime.datetime(2017, 5, 2, 0, 0), 267199],
#    [datetime.datetime(2017, 5, 2, 4, 0), 267219],
#    [datetime.datetime(2017, 5, 2, 8, 0), 267274],
#    [datetime.datetime(2017, 5, 2, 12, 0), 267444],
#    [datetime.datetime(2017, 5, 2, 16, 0), 267775],
#    [datetime.datetime(2017, 5, 2, 20, 0), 268381],
#    [datetime.datetime(2017, 5, 3, 0, 0), 268663],
#    [datetime.datetime(2017, 5, 3, 4, 0), 268688],
#    [datetime.datetime(2017, 5, 3, 8, 0), 268738],
#    [datetime.datetime(2017, 5, 3, 12, 0), 268913],
#    [datetime.datetime(2017, 5, 3, 16, 0), 269218],
#    [datetime.datetime(2017, 5, 3, 20, 0), 269875],
#    [datetime.datetime(2017, 5, 4, 0, 0), 270155],
#    [datetime.datetime(2017, 5, 4, 4, 0), 270182],
#    [datetime.datetime(2017, 5, 4, 8, 0), 270226],
#    [datetime.datetime(2017, 5, 4, 12, 0), 270371],
#    [datetime.datetime(2017, 5, 4, 16, 0), 270645],
#    [datetime.datetime(2017, 5, 4, 20, 0), 271262],
#    [datetime.datetime(2017, 5, 5, 0, 0), 271551],
#    [datetime.datetime(2017, 5, 5, 4, 0), 271575],
#    [datetime.datetime(2017, 5, 5, 8, 0), 271618],
#    [datetime.datetime(2017, 5, 5, 12, 0), 271771],
#    [datetime.datetime(2017, 5, 5, 16, 0), 271919],
#    [datetime.datetime(2017, 5, 5, 20, 0), 272463],
#    [datetime.datetime(2017, 5, 6, 0, 0), 272722],
#    [datetime.datetime(2017, 5, 6, 4, 0), 272759],
#    [datetime.datetime(2017, 5, 6, 8, 0), 272773],
#    [datetime.datetime(2017, 5, 6, 12, 0), 272895],
#    [datetime.datetime(2017, 5, 6, 16, 0), 273144],
#    [datetime.datetime(2017, 5, 6, 20, 0), 273452],
#    [datetime.datetime(2017, 5, 7, 0, 0), 273680],
#    [datetime.datetime(2017, 5, 7, 4, 0), 273714],
#    [datetime.datetime(2017, 5, 7, 8, 0), 273729],
#    [datetime.datetime(2017, 5, 7, 12, 0), 273837],
#    [datetime.datetime(2017, 5, 7, 16, 0), 274026],
#    [datetime.datetime(2017, 5, 7, 20, 0), 274288],
#    [datetime.datetime(2017, 5, 8, 0, 0), 274478],
#    [datetime.datetime(2017, 5, 8, 4, 0), 274500],
#    [datetime.datetime(2017, 5, 8, 8, 0), 274554],
#    [datetime.datetime(2017, 5, 8, 12, 0), 274708],
#    [datetime.datetime(2017, 5, 8, 16, 0), 274985],
#    [datetime.datetime(2017, 5, 8, 20, 0), 275600],
#    [datetime.datetime(2017, 5, 9, 0, 0), 275844],
#    [datetime.datetime(2017, 5, 9, 4, 0), 275865],
#    [datetime.datetime(2017, 5, 9, 8, 0), 275910],
#    [datetime.datetime(2017, 5, 9, 12, 0), 276097],
#    [datetime.datetime(2017, 5, 9, 16, 0), 276389],
#    [datetime.datetime(2017, 5, 9, 20, 0), 276941],
#    [datetime.datetime(2017, 5, 10, 0, 0), 277169],
#    [datetime.datetime(2017, 5, 10, 4, 0), 277188],
#    [datetime.datetime(2017, 5, 10, 8, 0), 277233],
#    [datetime.datetime(2017, 5, 10, 12, 0), 277410],
#    [datetime.datetime(2017, 5, 10, 16, 0), 277728],
#    [datetime.datetime(2017, 5, 10, 20, 0), 278331],
#    [datetime.datetime(2017, 5, 11, 0, 0), 278643],
#    [datetime.datetime(2017, 5, 11, 4, 0), 278669],
#    [datetime.datetime(2017, 5, 11, 8, 0), 278701],
#    [datetime.datetime(2017, 5, 11, 12, 0), 278862],
#    [datetime.datetime(2017, 5, 11, 16, 0), 279162],
#    [datetime.datetime(2017, 5, 11, 20, 0), 279767],
#    [datetime.datetime(2017, 5, 12, 0, 0), 280059],
#    [datetime.datetime(2017, 5, 12, 4, 0), 280083],
#    [datetime.datetime(2017, 5, 12, 8, 0), 280121],
#    [datetime.datetime(2017, 5, 12, 12, 0), 280297],
#    [datetime.datetime(2017, 5, 12, 16, 0), 280624],
#    [datetime.datetime(2017, 5, 12, 20, 0), 281260],
#    [datetime.datetime(2017, 5, 13, 0, 0), 281519],
#    [datetime.datetime(2017, 5, 13, 4, 0), 281572],
#    [datetime.datetime(2017, 5, 13, 8, 0), 281591],
#    [datetime.datetime(2017, 5, 13, 12, 0), 281695],
#    [datetime.datetime(2017, 5, 13, 16, 0), 281926],
#    [datetime.datetime(2017, 5, 13, 20, 0), 282204],
#    [datetime.datetime(2017, 5, 14, 0, 0), 282362],
#    [datetime.datetime(2017, 5, 14, 4, 0), 282399],
#    [datetime.datetime(2017, 5, 14, 8, 0), 282422],
#    [datetime.datetime(2017, 5, 14, 12, 0), 282538],
#    [datetime.datetime(2017, 5, 14, 16, 0), 282724],
#    [datetime.datetime(2017, 5, 14, 20, 0), 282963],
#    [datetime.datetime(2017, 5, 15, 0, 0), 283120],
#    [datetime.datetime(2017, 5, 15, 4, 0), 283138],
#    [datetime.datetime(2017, 5, 15, 8, 0), 283183],
#    [datetime.datetime(2017, 5, 15, 12, 0), 283353],
#    [datetime.datetime(2017, 5, 15, 16, 0), 283675],
#    [datetime.datetime(2017, 5, 15, 20, 0), 284256],
#    [datetime.datetime(2017, 5, 16, 0, 0), 284525],
#    [datetime.datetime(2017, 5, 16, 4, 0), 284547],
#    [datetime.datetime(2017, 5, 16, 8, 0), 284607],
#    [datetime.datetime(2017, 5, 16, 12, 0), 284762],
#    [datetime.datetime(2017, 5, 16, 16, 0), 285094],
#    [datetime.datetime(2017, 5, 16, 20, 0), 285786],
#    [datetime.datetime(2017, 5, 17, 0, 0), 286050],
#    [datetime.datetime(2017, 5, 17, 4, 0), 286052],
#    [datetime.datetime(2017, 5, 17, 8, 0), 286089],
#    [datetime.datetime(2017, 5, 17, 12, 0), 286278],
#    [datetime.datetime(2017, 5, 17, 16, 0), 286573],
#    [datetime.datetime(2017, 5, 17, 20, 0), 287113],
#    [datetime.datetime(2017, 5, 18, 0, 0), 287455],
#    [datetime.datetime(2017, 5, 18, 4, 0), 287464],
#    [datetime.datetime(2017, 5, 18, 8, 0), 287510],
#    [datetime.datetime(2017, 5, 18, 12, 0), 287685],
#    [datetime.datetime(2017, 5, 18, 16, 0), 288051],
#    [datetime.datetime(2017, 5, 18, 20, 0), 288783],
#    [datetime.datetime(2017, 5, 19, 0, 0), 289154],
#    [datetime.datetime(2017, 5, 19, 4, 0), 289157],
#    [datetime.datetime(2017, 5, 19, 8, 0), 289206],
#    [datetime.datetime(2017, 5, 19, 12, 0), 289447],
#    [datetime.datetime(2017, 5, 19, 16, 0), 289856],
#    [datetime.datetime(2017, 5, 19, 20, 0), 290691],
#    [datetime.datetime(2017, 5, 20, 0, 0), 291047],
#    [datetime.datetime(2017, 5, 20, 4, 0), 291096],
#    [datetime.datetime(2017, 5, 20, 8, 0), 291124],
#    [datetime.datetime(2017, 5, 20, 12, 0), 291279],
#    [datetime.datetime(2017, 5, 20, 16, 0), 291524],
#    [datetime.datetime(2017, 5, 20, 20, 0), 291851],
#    [datetime.datetime(2017, 5, 21, 0, 0), 292109],
#    [datetime.datetime(2017, 5, 21, 4, 0), 292149],
#    [datetime.datetime(2017, 5, 21, 8, 0), 292169],
#    [datetime.datetime(2017, 5, 21, 12, 0), 292265],
#    [datetime.datetime(2017, 5, 21, 16, 0), 292461],
#    [datetime.datetime(2017, 5, 21, 20, 0), 292733],
#    [datetime.datetime(2017, 5, 22, 0, 0), 292890],
#    [datetime.datetime(2017, 5, 22, 4, 0), 292905],
#    [datetime.datetime(2017, 5, 22, 8, 0), 292941],
#    [datetime.datetime(2017, 5, 22, 12, 0), 293094],
#    [datetime.datetime(2017, 5, 22, 16, 0), 293371],
#    [datetime.datetime(2017, 5, 22, 20, 0), 293890],
#    [datetime.datetime(2017, 5, 23, 0, 0), 294142],
#    [datetime.datetime(2017, 5, 23, 4, 0), 294164],
#    [datetime.datetime(2017, 5, 23, 8, 0), 294202],
#    [datetime.datetime(2017, 5, 23, 12, 0), 294371],
#    [datetime.datetime(2017, 5, 23, 16, 0), 294698],
#    [datetime.datetime(2017, 5, 23, 20, 0), 295276],
#    [datetime.datetime(2017, 5, 24, 0, 0), 295548],
#    [datetime.datetime(2017, 5, 24, 4, 0), 295571],
#    [datetime.datetime(2017, 5, 24, 8, 0), 295605],
#    [datetime.datetime(2017, 5, 24, 12, 0), 295805],
#    [datetime.datetime(2017, 5, 24, 16, 0), 296140],
#    [datetime.datetime(2017, 5, 24, 20, 0), 296714],
#    [datetime.datetime(2017, 5, 25, 0, 0), 297008],
#    [datetime.datetime(2017, 5, 25, 4, 0), 297039],
#    [datetime.datetime(2017, 5, 25, 8, 0), 297086],
#    [datetime.datetime(2017, 5, 25, 12, 0), 297249],
#    [datetime.datetime(2017, 5, 25, 16, 0), 297551],
#    [datetime.datetime(2017, 5, 25, 20, 0), 298151],
#    [datetime.datetime(2017, 5, 26, 0, 0), 298430],
#    [datetime.datetime(2017, 5, 26, 4, 0), 298460],
#    [datetime.datetime(2017, 5, 26, 8, 0), 298509],
#    [datetime.datetime(2017, 5, 26, 12, 0), 298690],
#    [datetime.datetime(2017, 5, 26, 16, 0), 299051],
#    [datetime.datetime(2017, 5, 26, 20, 0), 299531]]),
#  (('A002', 'R051', '02-03-02', '59 ST'),
#   [[datetime.datetime(2017, 4, 29, 0, 0), 5351047],
#    [datetime.datetime(2017, 4, 29, 4, 0), 5351095],
#    [datetime.datetime(2017, 4, 29, 8, 0), 5351136],
#    [datetime.datetime(2017, 4, 29, 12, 0), 5351316],
#    [datetime.datetime(2017, 4, 29, 16, 0), 5351590],
#    [datetime.datetime(2017, 4, 29, 20, 0), 5351871],
#    [datetime.datetime(2017, 4, 30, 0, 0), 5352096],
#    [datetime.datetime(2017, 4, 30, 4, 0), 5352136],
#    [datetime.datetime(2017, 4, 30, 8, 0), 5352151],
#    [datetime.datetime(2017, 4, 30, 12, 0), 5352227],
#    [datetime.datetime(2017, 4, 30, 16, 0), 5352400],
#    [datetime.datetime(2017, 4, 30, 20, 0), 5352619],
#    [datetime.datetime(2017, 5, 1, 0, 0), 5352740],
#    [datetime.datetime(2017, 5, 1, 4, 0), 5352756],
#    [datetime.datetime(2017, 5, 1, 8, 0), 5352795],
#    [datetime.datetime(2017, 5, 1, 12, 0), 5352990],
#    [datetime.datetime(2017, 5, 1, 16, 0), 5353284],
#    [datetime.datetime(2017, 5, 1, 20, 0), 5353872],
#    [datetime.datetime(2017, 5, 2, 0, 0), 5354016],
#    [datetime.datetime(2017, 5, 2, 4, 0), 5354034],
#    [datetime.datetime(2017, 5, 2, 8, 0), 5354073],
#    [datetime.datetime(2017, 5, 2, 12, 0), 5354246],
#    [datetime.datetime(2017, 5, 2, 16, 0), 5354565],
#    [datetime.datetime(2017, 5, 2, 20, 0), 5355201],
#    [datetime.datetime(2017, 5, 3, 0, 0), 5355434],
#    [datetime.datetime(2017, 5, 3, 4, 0), 5355454],
#    [datetime.datetime(2017, 5, 3, 8, 0), 5355512],
#    [datetime.datetime(2017, 5, 3, 12, 0), 5355705],
#    [datetime.datetime(2017, 5, 3, 16, 0), 5356004],
#    [datetime.datetime(2017, 5, 3, 20, 0), 5356649],
#    [datetime.datetime(2017, 5, 4, 0, 0), 5356893],
#    [datetime.datetime(2017, 5, 4, 4, 0), 5356916],
#    [datetime.datetime(2017, 5, 4, 8, 0), 5356953],
#    [datetime.datetime(2017, 5, 4, 12, 0), 5357127],
#    [datetime.datetime(2017, 5, 4, 16, 0), 5357447],
#    [datetime.datetime(2017, 5, 4, 20, 0), 5358090],
#    [datetime.datetime(2017, 5, 5, 0, 0), 5358336],
#    [datetime.datetime(2017, 5, 5, 4, 0), 5358359],
#    [datetime.datetime(2017, 5, 5, 8, 0), 5358402],
#    [datetime.datetime(2017, 5, 5, 12, 0), 5358585],
#    [datetime.datetime(2017, 5, 5, 16, 0), 5358731],
#    [datetime.datetime(2017, 5, 5, 20, 0), 5359281],
#    [datetime.datetime(2017, 5, 6, 0, 0), 5359515],
#    [datetime.datetime(2017, 5, 6, 4, 0), 5359547],
#    [datetime.datetime(2017, 5, 6, 8, 0), 5359574],
#    [datetime.datetime(2017, 5, 6, 12, 0), 5359681],
#    [datetime.datetime(2017, 5, 6, 16, 0), 5359917],
#    [datetime.datetime(2017, 5, 6, 20, 0), 5360185],
#    [datetime.datetime(2017, 5, 7, 0, 0), 5360348],
#    [datetime.datetime(2017, 5, 7, 4, 0), 5360370],
#    [datetime.datetime(2017, 5, 7, 8, 0), 5360389],
#    [datetime.datetime(2017, 5, 7, 12, 0), 5360468],
#    [datetime.datetime(2017, 5, 7, 16, 0), 5360651],
#    [datetime.datetime(2017, 5, 7, 20, 0), 5360876],
#    [datetime.datetime(2017, 5, 8, 0, 0), 5361044],
#    [datetime.datetime(2017, 5, 8, 4, 0), 5361064],
#    [datetime.datetime(2017, 5, 8, 8, 0), 5361112],
#    [datetime.datetime(2017, 5, 8, 12, 0), 5361317],
#    [datetime.datetime(2017, 5, 8, 16, 0), 5361582],
#    [datetime.datetime(2017, 5, 8, 20, 0), 5362199],
#    [datetime.datetime(2017, 5, 9, 0, 0), 5362448],
#    [datetime.datetime(2017, 5, 9, 4, 0), 5362462],
#    [datetime.datetime(2017, 5, 9, 8, 0), 5362510],
#    [datetime.datetime(2017, 5, 9, 12, 0), 5362722],
#    [datetime.datetime(2017, 5, 9, 16, 0), 5363033],
#    [datetime.datetime(2017, 5, 9, 20, 0), 5363684],
#    [datetime.datetime(2017, 5, 10, 0, 0), 5363920],
#    [datetime.datetime(2017, 5, 10, 4, 0), 5363944],
#    [datetime.datetime(2017, 5, 10, 8, 0), 5363978],
#    [datetime.datetime(2017, 5, 10, 12, 0), 5364145],
#    [datetime.datetime(2017, 5, 10, 16, 0), 5364447],
#    [datetime.datetime(2017, 5, 10, 20, 0), 5365066],
#    [datetime.datetime(2017, 5, 11, 0, 0), 5365313],
#    [datetime.datetime(2017, 5, 11, 4, 0), 5365336],
#    [datetime.datetime(2017, 5, 11, 8, 0), 5365380],
#    [datetime.datetime(2017, 5, 11, 12, 0), 5365554],
#    [datetime.datetime(2017, 5, 11, 16, 0), 5365850],
#    [datetime.datetime(2017, 5, 11, 20, 0), 5366439],
#    [datetime.datetime(2017, 5, 12, 0, 0), 5366712],
#    [datetime.datetime(2017, 5, 12, 4, 0), 5366742],
#    [datetime.datetime(2017, 5, 12, 8, 0), 5366813],
#    [datetime.datetime(2017, 5, 12, 12, 0), 5367000],
#    [datetime.datetime(2017, 5, 12, 16, 0), 5367279],
#    [datetime.datetime(2017, 5, 12, 20, 0), 5367956],
#    [datetime.datetime(2017, 5, 13, 0, 0), 5368197],
#    [datetime.datetime(2017, 5, 13, 4, 0), 5368245],
#    [datetime.datetime(2017, 5, 13, 8, 0), 5368267],
#    [datetime.datetime(2017, 5, 13, 12, 0), 5368373],
#    [datetime.datetime(2017, 5, 13, 16, 0), 5368584],
#    [datetime.datetime(2017, 5, 13, 20, 0), 5368812],
#    [datetime.datetime(2017, 5, 14, 0, 0), 5368979],
#    [datetime.datetime(2017, 5, 14, 4, 0), 5369007],
#    [datetime.datetime(2017, 5, 14, 8, 0), 5369024],
#    [datetime.datetime(2017, 5, 14, 12, 0), 5369120],
#    [datetime.datetime(2017, 5, 14, 16, 0), 5369309],
#    [datetime.datetime(2017, 5, 14, 20, 0), 5369523],
#    [datetime.datetime(2017, 5, 15, 0, 0), 5369668],
#    [datetime.datetime(2017, 5, 15, 4, 0), 5369677],
#    [datetime.datetime(2017, 5, 15, 8, 0), 5369715],
#    [datetime.datetime(2017, 5, 15, 12, 0), 5369879],
#    [datetime.datetime(2017, 5, 15, 16, 0), 5370154],
#    [datetime.datetime(2017, 5, 15, 20, 0), 5370783],
#    [datetime.datetime(2017, 5, 16, 0, 0), 5371010],
#    [datetime.datetime(2017, 5, 16, 4, 0), 5371031],
#    [datetime.datetime(2017, 5, 16, 8, 0), 5371071],
#    [datetime.datetime(2017, 5, 16, 12, 0), 5371284],
#    [datetime.datetime(2017, 5, 16, 16, 0), 5371577],
#    [datetime.datetime(2017, 5, 16, 20, 0), 5372263],
#    [datetime.datetime(2017, 5, 17, 0, 0), 5372531],
#    [datetime.datetime(2017, 5, 17, 4, 0), 5372534],
#    [datetime.datetime(2017, 5, 17, 8, 0), 5372571],
#    [datetime.datetime(2017, 5, 17, 12, 0), 5372752],
#    [datetime.datetime(2017, 5, 17, 16, 0), 5373050],
#    [datetime.datetime(2017, 5, 17, 20, 0), 5373666],
#    [datetime.datetime(2017, 5, 18, 0, 0), 5373742],
#    [datetime.datetime(2017, 5, 18, 4, 0), 5373742],
#    [datetime.datetime(2017, 5, 18, 8, 0), 5373742],
#    [datetime.datetime(2017, 5, 18, 12, 0), 5373811],
#    [datetime.datetime(2017, 5, 18, 16, 0), 5373811],
#    [datetime.datetime(2017, 5, 18, 20, 0), 5373811],
#    [datetime.datetime(2017, 5, 19, 0, 0), 5373811],
#    [datetime.datetime(2017, 5, 19, 4, 0), 5373811],
#    [datetime.datetime(2017, 5, 19, 8, 0), 5373811],
#    [datetime.datetime(2017, 5, 19, 12, 0), 5373811],
#    [datetime.datetime(2017, 5, 19, 16, 0), 5373827],
#    [datetime.datetime(2017, 5, 19, 20, 0), 5373880],
#    [datetime.datetime(2017, 5, 20, 0, 0), 5373880],
#    [datetime.datetime(2017, 5, 20, 4, 0), 5373880],
#    [datetime.datetime(2017, 5, 20, 8, 0), 5373880],
#    [datetime.datetime(2017, 5, 20, 12, 0), 5373880],
#    [datetime.datetime(2017, 5, 20, 16, 0), 5373948],
#    [datetime.datetime(2017, 5, 20, 20, 0), 5374004],
#    [datetime.datetime(2017, 5, 21, 0, 0), 5374025],
#    [datetime.datetime(2017, 5, 21, 4, 0), 5374025],
#    [datetime.datetime(2017, 5, 21, 8, 0), 5374025],
#    [datetime.datetime(2017, 5, 21, 12, 0), 5374109],
#    [datetime.datetime(2017, 5, 21, 16, 0), 5374270],
#    [datetime.datetime(2017, 5, 21, 20, 0), 5374490],
#    [datetime.datetime(2017, 5, 22, 0, 0), 5374622],
#    [datetime.datetime(2017, 5, 22, 4, 0), 5374631],
#    [datetime.datetime(2017, 5, 22, 8, 0), 5374673],
#    [datetime.datetime(2017, 5, 22, 12, 0), 5374853],
#    [datetime.datetime(2017, 5, 22, 16, 0), 5375121],
#    [datetime.datetime(2017, 5, 22, 20, 0), 5375676],
#    [datetime.datetime(2017, 5, 23, 0, 0), 5375903],
#    [datetime.datetime(2017, 5, 23, 4, 0), 5375921],
#    [datetime.datetime(2017, 5, 23, 8, 0), 5375956],
#    [datetime.datetime(2017, 5, 23, 12, 0), 5376174],
#    [datetime.datetime(2017, 5, 23, 16, 0), 5376489],
#    [datetime.datetime(2017, 5, 23, 20, 0), 5377124],
#    [datetime.datetime(2017, 5, 24, 0, 0), 5377349],
#    [datetime.datetime(2017, 5, 24, 4, 0), 5377374],
#    [datetime.datetime(2017, 5, 24, 8, 0), 5377427],
#    [datetime.datetime(2017, 5, 24, 12, 0), 5377693],
#    [datetime.datetime(2017, 5, 24, 16, 0), 5377987],
#    [datetime.datetime(2017, 5, 24, 20, 0), 5378608],
#    [datetime.datetime(2017, 5, 25, 0, 0), 5378861],
#    [datetime.datetime(2017, 5, 25, 4, 0), 5378887],
#    [datetime.datetime(2017, 5, 25, 8, 0), 5378931],
#    [datetime.datetime(2017, 5, 25, 12, 0), 5379136],
#    [datetime.datetime(2017, 5, 25, 16, 0), 5379457],
#    [datetime.datetime(2017, 5, 25, 20, 0), 5380079],
#    [datetime.datetime(2017, 5, 26, 0, 0), 5380322],
#    [datetime.datetime(2017, 5, 26, 4, 0), 5380348],
#    [datetime.datetime(2017, 5, 26, 8, 0), 5380385],
#    [datetime.datetime(2017, 5, 26, 12, 0), 5380570],
#    [datetime.datetime(2017, 5, 26, 16, 0), 5380917],
#    [datetime.datetime(2017, 5, 26, 20, 0), 5381425]])]

# %%
def convert_to_daily_time_series(combined_time_series):
    
    '''Iterates over the combined_time_series, calling the daily_calculation function to 
    calculate total entries in each day for each turnstile. Returns the total entries for each 
    turnstile in combined_time_series'''
    
    turnstile_daily_time_series = {}
    
    for i, (turnstile, time_series) in enumerate(combined_time_series.items()):
        print('Processing turnstile', turnstile)
        turnstile_daily_time_series[turnstile] = daily_calculation(time_series) # Creates a dict
        # where the key is the turnstile and the value is the total number of entries
    
    return turnstile_daily_time_series

# %%
from itertools import groupby

def count_within_normal_bounds(count):
    '''Checks whether the calculated turnstile count is within a normal range (i.e. greater
    than 0 and less than 10,000). If count is none, returns true'''
    
    if count is None:
        return True
    else:
        return 10000 > count >= 0
    
def daily_calculation(time_series):
    '''Calculates the entry count for a each turnstile each day'''
    daily_time_series = []
    
    def day_of_timestamp(entry):
        '''takes an entry from from the time series and returns the date'''
        
        timestamp, tot_entries = entry
        return timestamp.date()
    
    count_on_previous_day = None
    for day, entries_on_this_day in groupby(time_series, key=day_of_timestamp):
        cum_entry_count_on_day = max([count for time, count in entries_on_this_day])
        
        if count_on_previous_day is None:
            daily_entries = None
        else:
            daily_entries = cum_entry_count_on_day - count_on_previous_day
        
        count_on_previous_day = cum_entry_count_on_day
        
        if count_within_normal_bounds(daily_entries):
            daily_time_series.append((day, daily_entries))
            
        else: 
            print('Warning: Abnormal entry count found on day {}: {}'.format(day, daily_entries))
            daily_time_series.append((day, None))

    return daily_time_series

# %%
daily_time_series = convert_to_daily_time_series(combined_time_series)
# Out:
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST')
# Processing turnstile ('A002', 'R051', '02-00-01', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-00', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-01', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-02', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-03', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-04', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-05', '59 ST')
# Processing turnstile ('A002', 'R051', '02-03-06', '59 ST')
# Processing turnstile ('A002', 'R051', '02-05-00', '59 ST')
# Processing turnstile ('A002', 'R051', '02-05-01', '59 ST')
# Processing turnstile ('A002', 'R051', '02-06-00', '59 ST')
# Processing turnstile ('A006', 'R079', '00-00-00', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-00-01', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-00-02', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-00-03', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-00-04', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-03-00', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-03-01', '5 AV/59 ST')
# Processing turnstile ('A006', 'R079', '00-03-02', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-05-00', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-05-01', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-06-00', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-06-01', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-06-02', '5 AV/59 ST')
# Processing turnstile ('A007', 'R079', '01-06-03', '5 AV/59 ST')
# Processing turnstile ('A010', 'R080', '00-00-00', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-01', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-02', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-03', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-04', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-05', '57 ST-7 AV')
# Warning: Abnormal entry count found on day 2017-05-16: -424894
# Processing turnstile ('A010', 'R080', '00-00-06', '57 ST-7 AV')
# Processing turnstile ('A010', 'R080', '00-00-07', '57 ST-7 AV')
# Processing turnstile ('A011', 'R080', '01-00-00', '57 ST-7 AV')
# Warning: Abnormal entry count found on day 2017-04-30: -2157
# Warning: Abnormal entry count found on day 2017-05-01: -1821
# Warning: Abnormal entry count found on day 2017-05-02: -2673
# Warning: Abnormal entry count found on day 2017-05-03: -3602
# Warning: Abnormal entry count found on day 2017-05-04: -3631
# Warning: Abnormal entry count found on day 2017-05-05: -3593
# Warning: Abnormal entry count found on day 2017-05-06: -3241
# Warning: Abnormal entry count found on day 2017-05-07: -1961
# Warning: Abnormal entry count found on day 2017-05-08: -1600
# Warning: Abnormal entry count found on day 2017-05-09: -3268
# Warning: Abnormal entry count found on day 2017-05-10: -3371
# Warning: Abnormal entry count found on day 2017-05-11: -3314
# Warning: Abnormal entry count found on day 2017-05-12: -3725
# Warning: Abnormal entry count found on day 2017-05-13: -3578
# Warning: Abnormal entry count found on day 2017-05-14: -2070
# Warning: Abnormal entry count found on day 2017-05-15: -1602
# Warning: Abnormal entry count found on day 2017-05-16: -3232
# Warning: Abnormal entry count found on day 2017-05-17: -3477
# Warning: Abnormal entry count found on day 2017-05-18: -3373
# Warning: Abnormal entry count found on day 2017-05-19: -3521
# Warning: Abnormal entry count found on day 2017-05-20: -3159
# Warning: Abnormal entry count found on day 2017-05-21: -1699
# Warning: Abnormal entry count found on day 2017-05-22: -1971
# Warning: Abnormal entry count found on day 2017-05-23: -3432
# Warning: Abnormal entry count found on day 2017-05-24: -3664
# Warning: Abnormal entry count found on day 2017-05-25: -3664
# Warning: Abnormal entry count found on day 2017-05-26: -3576
# Processing turnstile ('A011', 'R080', '01-00-01', '57 ST-7 AV')
# Processing turnstile ('A011', 'R080', '01-00-02', '57 ST-7 AV')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AV')
# Processing turnstile ('A011', 'R080', '01-00-04', '57 ST-7 AV')
# Processing turnstile ('A011', 'R080', '01-00-05', '57 ST-7 AV')
# Processing turnstile ('A013', 'R081', '01-00-00', '49 ST')
# Processing turnstile ('A013', 'R081', '01-03-00', '49 ST')
# Processing turnstile ('A013', 'R081', '01-03-01', '49 ST')
# Processing turnstile ('A013', 'R081', '01-03-02', '49 ST')
# Processing turnstile ('A013', 'R081', '01-05-00', '49 ST')
# Processing turnstile ('A013', 'R081', '01-05-01', '49 ST')
# Processing turnstile ('A014', 'R081', '02-00-00', '49 ST')
# Processing turnstile ('A014', 'R081', '02-00-01', '49 ST')
# Processing turnstile ('A014', 'R081', '02-00-02', '49 ST')
# Processing turnstile ('A014', 'R081', '02-06-00', '49 ST')
# Processing turnstile ('A014', 'R081', '02-06-01', '49 ST')
# Processing turnstile ('A015', 'R081', '00-00-00', '49 ST')
# Processing turnstile ('A015', 'R081', '00-00-01', '49 ST')
# Processing turnstile ('A015', 'R081', '00-00-02', '49 ST')
# Processing turnstile ('A015', 'R081', '00-00-03', '49 ST')
# Processing turnstile ('A015', 'R081', '00-03-00', '49 ST')
# Processing turnstile ('A015', 'R081', '00-03-01', '49 ST')
# Processing turnstile ('A016', 'R081', '03-00-00', '49 ST')
# Processing turnstile ('A016', 'R081', '03-00-01', '49 ST')
# Processing turnstile ('A016', 'R081', '03-00-02', '49 ST')
# Processing turnstile ('A016', 'R081', '03-06-00', '49 ST')
# Processing turnstile ('A016', 'R081', '03-06-01', '49 ST')
# Processing turnstile ('A021', 'R032', '01-00-00', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-01', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-02', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-03', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-04', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-05', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-06', 'TIMES SQ-42 ST')
# Processing turnstile ('A021', 'R032', '01-00-07', 'TIMES SQ-42 ST')
# Processing turnstile ('A022', 'R022', '01-00-00', '34 ST-HERALD SQ')
# Processing turnstile ('A022', 'R022', '01-00-01', '34 ST-HERALD SQ')
# Processing turnstile ('A022', 'R022', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('A022', 'R022', '01-06-00', '34 ST-HERALD SQ')
# Processing turnstile ('A022', 'R022', '01-06-01', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-00-00', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-00-01', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-00-03', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-03-00', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-03-01', '34 ST-HERALD SQ')
# Warning: Abnormal entry count found on day 2017-04-30: -2695
# Warning: Abnormal entry count found on day 2017-05-01: -2134
# Warning: Abnormal entry count found on day 2017-05-02: -4384
# Warning: Abnormal entry count found on day 2017-05-03: -4115
# Warning: Abnormal entry count found on day 2017-05-04: -4142
# Warning: Abnormal entry count found on day 2017-05-05: -4048
# Warning: Abnormal entry count found on day 2017-05-06: -4310
# Warning: Abnormal entry count found on day 2017-05-07: -2812
# Warning: Abnormal entry count found on day 2017-05-08: -2187
# Warning: Abnormal entry count found on day 2017-05-09: -3805
# Warning: Abnormal entry count found on day 2017-05-10: -3939
# Warning: Abnormal entry count found on day 2017-05-11: -3925
# Warning: Abnormal entry count found on day 2017-05-12: -4194
# Warning: Abnormal entry count found on day 2017-05-13: -4299
# Warning: Abnormal entry count found on day 2017-05-14: -2432
# Warning: Abnormal entry count found on day 2017-05-15: -1995
# Warning: Abnormal entry count found on day 2017-05-16: -4554
# Warning: Abnormal entry count found on day 2017-05-17: -4096
# Warning: Abnormal entry count found on day 2017-05-18: -5738
# Warning: Abnormal entry count found on day 2017-05-19: -5192
# Warning: Abnormal entry count found on day 2017-05-20: -4750
# Warning: Abnormal entry count found on day 2017-05-21: -2396
# Warning: Abnormal entry count found on day 2017-05-22: -1986
# Warning: Abnormal entry count found on day 2017-05-23: -3839
# Warning: Abnormal entry count found on day 2017-05-24: -4039
# Warning: Abnormal entry count found on day 2017-05-25: -4157
# Warning: Abnormal entry count found on day 2017-05-26: -4361
# Processing turnstile ('A025', 'R023', '01-03-02', '34 ST-HERALD SQ')
# Warning: Abnormal entry count found on day 2017-04-30: -3287
# Warning: Abnormal entry count found on day 2017-05-01: -2791
# Warning: Abnormal entry count found on day 2017-05-02: -4307
# Warning: Abnormal entry count found on day 2017-05-03: -4554
# Warning: Abnormal entry count found on day 2017-05-04: -4646
# Warning: Abnormal entry count found on day 2017-05-05: -4730
# Warning: Abnormal entry count found on day 2017-05-06: -4260
# Warning: Abnormal entry count found on day 2017-05-07: -2076
# Warning: Abnormal entry count found on day 2017-05-08: -2467
# Warning: Abnormal entry count found on day 2017-05-09: -4314
# Warning: Abnormal entry count found on day 2017-05-10: -4589
# Warning: Abnormal entry count found on day 2017-05-11: -4715
# Warning: Abnormal entry count found on day 2017-05-12: -4913
# Warning: Abnormal entry count found on day 2017-05-13: -4799
# Warning: Abnormal entry count found on day 2017-05-14: -3034
# Warning: Abnormal entry count found on day 2017-05-15: -2644
# Warning: Abnormal entry count found on day 2017-05-16: -2698
# Warning: Abnormal entry count found on day 2017-05-17: -4558
# Warning: Abnormal entry count found on day 2017-05-18: -4611
# Warning: Abnormal entry count found on day 2017-05-19: -4713
# Warning: Abnormal entry count found on day 2017-05-20: -4615
# Warning: Abnormal entry count found on day 2017-05-21: -3133
# Warning: Abnormal entry count found on day 2017-05-22: -2614
# Warning: Abnormal entry count found on day 2017-05-23: -4485
# Warning: Abnormal entry count found on day 2017-05-24: -4645
# Warning: Abnormal entry count found on day 2017-05-25: -4730
# Warning: Abnormal entry count found on day 2017-05-26: -4568
# Processing turnstile ('A025', 'R023', '01-06-00', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-06-01', '34 ST-HERALD SQ')
# Processing turnstile ('A025', 'R023', '01-06-02', '34 ST-HERALD SQ')
# Processing turnstile ('A027', 'R082', '01-00-00', '28 ST')
# Processing turnstile ('A027', 'R082', '01-03-00', '28 ST')
# Processing turnstile ('A027', 'R082', '01-03-01', '28 ST')
# Processing turnstile ('A027', 'R082', '01-03-02', '28 ST')
# Processing turnstile ('A027', 'R082', '01-03-03', '28 ST')
# Processing turnstile ('A029', 'R082', '00-00-00', '28 ST')
# Processing turnstile ('A029', 'R082', '00-00-01', '28 ST')
# Processing turnstile ('A029', 'R082', '00-03-00', '28 ST')
# Processing turnstile ('A029', 'R082', '00-03-01', '28 ST')
# Processing turnstile ('A030', 'R083', '01-00-00', '23 ST')
# Processing turnstile ('A030', 'R083', '01-00-01', '23 ST')
# Processing turnstile ('A030', 'R083', '01-00-02', '23 ST')
# Processing turnstile ('A030', 'R083', '01-03-00', '23 ST')
# Processing turnstile ('A030', 'R083', '01-03-01', '23 ST')
# Processing turnstile ('A030', 'R083', '01-03-02', '23 ST')
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST')
# Processing turnstile ('A030', 'R083', '01-06-01', '23 ST')
# Processing turnstile ('A031', 'R083', '00-00-00', '23 ST')
# Processing turnstile ('A031', 'R083', '00-00-01', '23 ST')
# Processing turnstile ('A031', 'R083', '00-00-02', '23 ST')
# Processing turnstile ('A031', 'R083', '00-03-00', '23 ST')
# Processing turnstile ('A031', 'R083', '00-03-01', '23 ST')
# Processing turnstile ('A031', 'R083', '00-03-02', '23 ST')
# Processing turnstile ('A033', 'R170', '02-00-00', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-00-01', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-00-02', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-00-03', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-00-04', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-00-05', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-06-00', '14 ST-UNION SQ')
# Processing turnstile ('A033', 'R170', '02-06-01', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-00-00', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-00-01', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-00-02', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-03-00', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-03-01', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-03-02', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-06-00', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-06-01', '14 ST-UNION SQ')
# Processing turnstile ('A034', 'R170', '03-06-02', '14 ST-UNION SQ')
# Processing turnstile ('A035', 'R170', '00-00-00', '14 ST-UNION SQ')
# Processing turnstile ('A035', 'R170', '00-00-01', '14 ST-UNION SQ')
# Processing turnstile ('A035', 'R170', '00-00-02', '14 ST-UNION SQ')
# Processing turnstile ('A035', 'R170', '00-00-03', '14 ST-UNION SQ')
# Processing turnstile ('A035', 'R170', '00-00-04', '14 ST-UNION SQ')
# Processing turnstile ('A037', 'R170', '05-00-00', '14 ST-UNION SQ')
# Warning: Abnormal entry count found on day 2017-05-25: -682265
# Processing turnstile ('A037', 'R170', '05-00-01', '14 ST-UNION SQ')
# Processing turnstile ('A037', 'R170', '05-00-02', '14 ST-UNION SQ')
# Processing turnstile ('A037', 'R170', '05-00-03', '14 ST-UNION SQ')
# Processing turnstile ('A038', 'R085', '00-00-00', '8 ST-NYU')
# Processing turnstile ('A038', 'R085', '00-00-01', '8 ST-NYU')
# Processing turnstile ('A038', 'R085', '00-00-02', '8 ST-NYU')
# Processing turnstile ('A038', 'R085', '00-00-03', '8 ST-NYU')
# Processing turnstile ('A038', 'R085', '00-00-04', '8 ST-NYU')
# Processing turnstile ('A038', 'R085', '00-06-00', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-00-00', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-00-01', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-00-02', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-03-00', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-03-01', '8 ST-NYU')
# Processing turnstile ('A039', 'R085', '01-06-00', '8 ST-NYU')
# Processing turnstile ('A041', 'R086', '00-00-00', 'PRINCE ST')
# Processing turnstile ('A041', 'R086', '00-00-01', 'PRINCE ST')
# Processing turnstile ('A041', 'R086', '00-00-02', 'PRINCE ST')
# Processing turnstile ('A041', 'R086', '00-00-03', 'PRINCE ST')
# Processing turnstile ('A041', 'R086', '00-00-04', 'PRINCE ST')
# Processing turnstile ('A042', 'R086', '01-00-00', 'PRINCE ST')
# Processing turnstile ('A042', 'R086', '01-00-01', 'PRINCE ST')
# Processing turnstile ('A042', 'R086', '01-00-02', 'PRINCE ST')
# Processing turnstile ('A042', 'R086', '01-00-03', 'PRINCE ST')
# Processing turnstile ('A042', 'R086', '01-00-04', 'PRINCE ST')
# Processing turnstile ('A043', 'R462', '00-00-00', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-00-01', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-00-02', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-03-00', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-03-01', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-03-02', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-03-03', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-03-04', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-06-00', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-06-01', 'CANAL ST')
# Processing turnstile ('A043', 'R462', '00-06-02', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-00-00', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-00-01', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-00-02', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-00-03', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-03-00', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-03-01', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-05-00', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-05-01', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-05-02', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-05-03', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-00', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-01', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-02', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-03', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-04', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-05', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-06', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-07', 'CANAL ST')
# Processing turnstile ('A046', 'R463', '00-06-08', 'CANAL ST')
# Processing turnstile ('A047', 'R087', '00-00-00', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-00-01', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-00-02', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-03-00', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-03-01', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-03-02', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-06-00', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-06-01', 'CITY HALL')
# Processing turnstile ('A047', 'R087', '00-06-02', 'CITY HALL')
# Processing turnstile ('A049', 'R088', '02-00-00', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-00-01', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-00-02', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-00-03', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-01-00', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-01-02', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-03-00', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-03-01', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-03-02', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-03-03', 'CORTLANDT ST')
# Processing turnstile ('A049', 'R088', '02-05-00', 'CORTLANDT ST')
# Warning: Abnormal entry count found on day 2017-04-30: -3
# Warning: Abnormal entry count found on day 2017-05-02: -3
# Warning: Abnormal entry count found on day 2017-05-03: -5
# Warning: Abnormal entry count found on day 2017-05-04: -4
# Warning: Abnormal entry count found on day 2017-05-07: -1
# Warning: Abnormal entry count found on day 2017-05-09: -2
# Warning: Abnormal entry count found on day 2017-05-10: -6
# Warning: Abnormal entry count found on day 2017-05-12: -3
# Warning: Abnormal entry count found on day 2017-05-13: -1
# Warning: Abnormal entry count found on day 2017-05-15: -1
# Warning: Abnormal entry count found on day 2017-05-16: -10
# Warning: Abnormal entry count found on day 2017-05-18: -1
# Warning: Abnormal entry count found on day 2017-05-20: -2
# Warning: Abnormal entry count found on day 2017-05-21: -1
# Warning: Abnormal entry count found on day 2017-05-22: -5
# Warning: Abnormal entry count found on day 2017-05-23: -7
# Warning: Abnormal entry count found on day 2017-05-25: -2
# Processing turnstile ('A049', 'R088', '02-05-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-00-00', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-00-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-02-00', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-02-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-03-00', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-03-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-03-02', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-03-03', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-05-00', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-05-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-05-02', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-05-03', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-06-00', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-06-01', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-06-02', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-06-03', 'CORTLANDT ST')
# Processing turnstile ('A050', 'R088', '00-06-04', 'CORTLANDT ST')
# Processing turnstile ('A054', 'R227', '01-00-00', 'RECTOR ST')
# Processing turnstile ('A054', 'R227', '01-00-01', 'RECTOR ST')
# Processing turnstile ('A054', 'R227', '01-00-02', 'RECTOR ST')
# Processing turnstile ('A054', 'R227', '01-03-00', 'RECTOR ST')
# Processing turnstile ('A054', 'R227', '01-03-01', 'RECTOR ST')
# Processing turnstile ('A054', 'R227', '01-06-00', 'RECTOR ST')
# Warning: Abnormal entry count found on day 2017-05-23: -100837169
# Processing turnstile ('A055', 'R227', '00-00-00', 'RECTOR ST')
# Processing turnstile ('A055', 'R227', '00-00-01', 'RECTOR ST')
# Processing turnstile ('A055', 'R227', '00-00-02', 'RECTOR ST')
# Processing turnstile ('A055', 'R227', '00-00-03', 'RECTOR ST')
# Processing turnstile ('A055', 'R227', '00-00-04', 'RECTOR ST')
# Processing turnstile ('A058', 'R001', '01-00-00', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-00-01', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-00-02', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-00-03', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-06-00', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-06-01', 'WHITEHALL S-FRY')
# Processing turnstile ('A058', 'R001', '01-06-02', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-00', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-01', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-02', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-03', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-04', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-05', 'WHITEHALL S-FRY')
# Processing turnstile ('A060', 'R001', '00-00-06', 'WHITEHALL S-FRY')
# Warning: Abnormal entry count found on day 2017-05-18: -548365
# Processing turnstile ('A060', 'R001', '00-00-07', 'WHITEHALL S-FRY')
# Processing turnstile ('A061', 'R142', '00-00-00', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-00-01', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-00-02', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-03-00', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-03-01', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-03-02', 'DELANCEY/ESSEX')
# Processing turnstile ('A061', 'R142', '00-03-03', 'DELANCEY/ESSEX')
# Processing turnstile ('A064', 'R311', '00-00-00', 'BOWERY')
# Processing turnstile ('A064', 'R311', '00-03-00', 'BOWERY')
# Processing turnstile ('A064', 'R311', '00-03-01', 'BOWERY')
# Processing turnstile ('A066', 'R118', '00-00-00', 'CANAL ST')
# Warning: Abnormal entry count found on day 2017-04-30: -3968
# Warning: Abnormal entry count found on day 2017-05-01: -3308
# Warning: Abnormal entry count found on day 2017-05-02: -4275
# Warning: Abnormal entry count found on day 2017-05-03: -4189
# Warning: Abnormal entry count found on day 2017-05-04: -4036
# Warning: Abnormal entry count found on day 2017-05-05: -3980
# Warning: Abnormal entry count found on day 2017-05-06: -3777
# Warning: Abnormal entry count found on day 2017-05-07: -4592
# Warning: Abnormal entry count found on day 2017-05-08: -3572
# Warning: Abnormal entry count found on day 2017-05-09: -4341
# Warning: Abnormal entry count found on day 2017-05-10: -4204
# Warning: Abnormal entry count found on day 2017-05-11: -4573
# Warning: Abnormal entry count found on day 2017-05-12: -4328
# Warning: Abnormal entry count found on day 2017-05-13: -4665
# Warning: Abnormal entry count found on day 2017-05-14: -2874
# Warning: Abnormal entry count found on day 2017-05-15: -3533
# Warning: Abnormal entry count found on day 2017-05-16: -4302
# Warning: Abnormal entry count found on day 2017-05-17: -4621
# Warning: Abnormal entry count found on day 2017-05-18: -5265
# Warning: Abnormal entry count found on day 2017-05-19: -4149
# Warning: Abnormal entry count found on day 2017-05-20: -4598
# Warning: Abnormal entry count found on day 2017-05-21: -4948
# Warning: Abnormal entry count found on day 2017-05-22: -4463
# Warning: Abnormal entry count found on day 2017-05-23: -3906
# Warning: Abnormal entry count found on day 2017-05-24: -4475
# Warning: Abnormal entry count found on day 2017-05-25: -4216
# Warning: Abnormal entry count found on day 2017-05-26: -3857
# Processing turnstile ('A066', 'R118', '00-00-01', 'CANAL ST')
# Processing turnstile ('A066', 'R118', '00-00-02', 'CANAL ST')
# Processing turnstile ('A069', 'R044', '01-00-00', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-00-01', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-00-02', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-00-03', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-00-04', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-06-00', 'CHAMBERS ST')
# Processing turnstile ('A069', 'R044', '01-06-01', 'CHAMBERS ST')
# Processing turnstile ('A071', 'R044', '02-00-00', 'CHAMBERS ST')
# Processing turnstile ('A071', 'R044', '02-00-01', 'CHAMBERS ST')
# Processing turnstile ('A071', 'R044', '02-00-02', 'CHAMBERS ST')
# Warning: Abnormal entry count found on day 2017-05-19: -2605859
# Processing turnstile ('A071', 'R044', '02-06-00', 'CHAMBERS ST')
# Processing turnstile ('A071', 'R044', '02-06-01', 'CHAMBERS ST')
# Processing turnstile ('A071', 'R044', '02-06-02', 'CHAMBERS ST')
# Processing turnstile ('A077', 'R028', '03-00-00', 'FULTON ST')
# Processing turnstile ('A077', 'R028', '03-03-00', 'FULTON ST')
# Processing turnstile ('A077', 'R028', '03-03-01', 'FULTON ST')
# Processing turnstile ('A077', 'R028', '03-03-02', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-00', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-01', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-02', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-03', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-04', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-05-00', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-05-01', 'FULTON ST')
# Processing turnstile ('A082', 'R028', '05-05-00', 'FULTON ST')
# Processing turnstile ('A082', 'R028', '05-05-01', 'FULTON ST')
# Processing turnstile ('A082', 'R028', '05-06-00', 'FULTON ST')
# Processing turnstile ('A082', 'R028', '05-06-01', 'FULTON ST')
# Processing turnstile ('A083', 'R125', '00-00-00', 'BROAD ST')
# Processing turnstile ('A083', 'R125', '00-00-01', 'BROAD ST')
# Processing turnstile ('A083', 'R125', '00-00-02', 'BROAD ST')
# Processing turnstile ('A083', 'R125', '00-00-03', 'BROAD ST')
# Processing turnstile ('A083', 'R125', '00-00-04', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-00-00', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-00-01', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-00-02', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-06-00', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-06-01', 'BROAD ST')
# Processing turnstile ('A084', 'R125', '01-06-02', 'BROAD ST')
# Processing turnstile ('A085', 'R125', '02-05-00', 'BROAD ST')
# Processing turnstile ('B004', 'R171', '00-00-00', '7 AV')
# Processing turnstile ('B004', 'R171', '00-00-01', '7 AV')
# Processing turnstile ('B004', 'R171', '00-00-02', '7 AV')
# Processing turnstile ('B004', 'R171', '00-00-03', '7 AV')
# Processing turnstile ('B009', 'R411', '00-00-00', 'PARK PLACE')
# Processing turnstile ('B009', 'R411', '00-00-01', 'PARK PLACE')
# Processing turnstile ('B009', 'R411', '00-00-02', 'PARK PLACE')
# Processing turnstile ('B009', 'R411', '00-05-00', 'PARK PLACE')
# Processing turnstile ('B009', 'R411', '00-05-01', 'PARK PLACE')
# Processing turnstile ('B010', 'R412', '00-00-00', 'BOTANIC GARDEN')
# Processing turnstile ('B010', 'R412', '00-03-00', 'BOTANIC GARDEN')
# Processing turnstile ('B010', 'R412', '00-03-01', 'BOTANIC GARDEN')
# Processing turnstile ('B010', 'R412', '00-03-02', 'BOTANIC GARDEN')
# Processing turnstile ('B012', 'R196', '00-00-00', 'PROSPECT PARK')
# Processing turnstile ('B012', 'R196', '00-00-01', 'PROSPECT PARK')
# Processing turnstile ('B012', 'R196', '00-03-00', 'PROSPECT PARK')
# Processing turnstile ('B013', 'R196', '01-00-00', 'PROSPECT PARK')
# Processing turnstile ('B013', 'R196', '01-00-01', 'PROSPECT PARK')
# Processing turnstile ('B013', 'R196', '01-00-02', 'PROSPECT PARK')
# Processing turnstile ('B013', 'R196', '01-05-00', 'PROSPECT PARK')
# Processing turnstile ('B013', 'R196', '01-05-01', 'PROSPECT PARK')
# Processing turnstile ('B014', 'R148', '00-00-00', 'PARKSIDE AV')
# Processing turnstile ('B014', 'R148', '00-00-01', 'PARKSIDE AV')
# Processing turnstile ('B014', 'R148', '00-00-02', 'PARKSIDE AV')
# Processing turnstile ('B015', 'R098', '01-00-00', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-00-01', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-00-02', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-00-03', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-03-00', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-03-01', 'CHURCH AV')
# Processing turnstile ('B015', 'R098', '01-06-00', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-00-00', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-00-01', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-00-02', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-00-03', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-03-00', 'CHURCH AV')
# Processing turnstile ('B016', 'R098', '00-03-01', 'CHURCH AV')
# Warning: Abnormal entry count found on day 2017-05-18: -4606724
# Processing turnstile ('B016', 'R098', '00-03-02', 'CHURCH AV')
# Processing turnstile ('B017', 'R262', '00-00-00', 'BEVERLEY ROAD')
# Processing turnstile ('B017', 'R262', '00-00-01', 'BEVERLEY ROAD')
# Processing turnstile ('B017', 'R262', '00-00-02', 'BEVERLEY ROAD')
# Processing turnstile ('B018', 'R184', '00-00-00', 'CORTELYOU RD')
# Processing turnstile ('B018', 'R184', '00-00-01', 'CORTELYOU RD')
# Processing turnstile ('B018', 'R184', '00-00-02', 'CORTELYOU RD')
# Processing turnstile ('B019', 'R149', '00-00-00', 'NEWKIRK PLAZA')
# Processing turnstile ('B019', 'R149', '00-00-01', 'NEWKIRK PLAZA')
# Processing turnstile ('B019', 'R149', '00-00-02', 'NEWKIRK PLAZA')
# Processing turnstile ('B019', 'R149', '00-00-03', 'NEWKIRK PLAZA')
# Processing turnstile ('B019', 'R149', '00-00-04', 'NEWKIRK PLAZA')
# Processing turnstile ('B020', 'R263', '00-00-00', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-00-01', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-00-02', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-03-00', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-03-01', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-03-02', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-05-00', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-05-01', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-05-02', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-00', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-01', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-02', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-03', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-04', 'AVENUE H')
# Processing turnstile ('B020', 'R263', '00-06-05', 'AVENUE H')
# Processing turnstile ('B021', 'R228', '00-00-00', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-00-01', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-00-02', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-00-03', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-00-04', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-03-00', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-03-01', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-03-02', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-04-00', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-04-01', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-05-00', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-05-01', 'AVENUE J')
# Processing turnstile ('B021', 'R228', '00-05-02', 'AVENUE J')
# Processing turnstile ('B022', 'R229', '00-00-00', 'AVENUE M')
# Warning: Abnormal entry count found on day 2017-04-30: 16006271
# Warning: Abnormal entry count found on day 2017-05-01: -16005558
# Processing turnstile ('B022', 'R229', '00-00-01', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-00-02', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-00-03', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-00-04', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-03-00', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-03-01', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-05-00', 'AVENUE M')
# Warning: Abnormal entry count found on day 2017-04-30: 16734978
# Warning: Abnormal entry count found on day 2017-05-02: -16795734
# Processing turnstile ('B022', 'R229', '00-05-01', 'AVENUE M')
# Processing turnstile ('B022', 'R229', '00-05-02', 'AVENUE M')
# Processing turnstile ('B023', 'R211', '01-05-00', 'KINGS HWY')
# Processing turnstile ('B023', 'R211', '01-05-01', 'KINGS HWY')
# Processing turnstile ('B023', 'R211', '01-06-00', 'KINGS HWY')
# Processing turnstile ('B023', 'R211', '01-06-01', 'KINGS HWY')
# Processing turnstile ('B023', 'R211', '01-06-02', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-00-00', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-00-01', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-00-02', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-05-00', 'KINGS HWY')
# Processing turnstile ('B024', 'R211', '00-05-01', 'KINGS HWY')
# Processing turnstile ('B024A', 'R211', '02-00-00', 'KINGS HWY')
# Processing turnstile ('B024A', 'R211', '02-00-01', 'KINGS HWY')
# Processing turnstile ('B024A', 'R211', '02-00-02', 'KINGS HWY')
# Processing turnstile ('B024A', 'R211', '02-00-03', 'KINGS HWY')
# Processing turnstile ('B024A', 'R211', '02-00-04', 'KINGS HWY')
# Processing turnstile ('B025', 'R150', '00-00-00', 'AVENUE U')
# Processing turnstile ('B025', 'R150', '00-00-01', 'AVENUE U')
# Processing turnstile ('B025', 'R150', '00-00-02', 'AVENUE U')
# Processing turnstile ('B025', 'R150', '00-00-03', 'AVENUE U')
# Processing turnstile ('B025', 'R150', '00-05-00', 'AVENUE U')
# Processing turnstile ('B025', 'R150', '00-05-01', 'AVENUE U')
# Processing turnstile ('B026', 'R230', '00-00-00', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-00-01', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-00-02', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-00-03', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-05-00', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-05-01', 'NECK RD')
# Processing turnstile ('B026', 'R230', '00-06-00', 'NECK RD')
# Processing turnstile ('B027', 'R136', '00-00-00', 'SHEEPSHEAD BAY')
# Processing turnstile ('B027', 'R136', '00-00-01', 'SHEEPSHEAD BAY')
# Processing turnstile ('B027', 'R136', '00-00-02', 'SHEEPSHEAD BAY')
# Processing turnstile ('B027', 'R136', '00-00-03', 'SHEEPSHEAD BAY')
# Processing turnstile ('B027', 'R136', '00-00-04', 'SHEEPSHEAD BAY')
# Processing turnstile ('B027', 'R136', '00-00-05', 'SHEEPSHEAD BAY')
# Processing turnstile ('B028', 'R136', '01-00-00', 'SHEEPSHEAD BAY')
# Processing turnstile ('B028', 'R136', '01-00-01', 'SHEEPSHEAD BAY')
# Processing turnstile ('B028', 'R136', '01-00-02', 'SHEEPSHEAD BAY')
# Processing turnstile ('B029', 'R172', '00-00-00', 'BRIGHTON BEACH')
# Processing turnstile ('B029', 'R172', '00-00-01', 'BRIGHTON BEACH')
# Processing turnstile ('B029', 'R172', '00-00-02', 'BRIGHTON BEACH')
# Processing turnstile ('B029', 'R172', '00-00-03', 'BRIGHTON BEACH')
# Processing turnstile ('B029', 'R172', '00-00-04', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-00-00', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-00-01', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-00-02', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-00-03', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-00-04', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-06-00', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-06-01', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-06-02', 'BRIGHTON BEACH')
# Processing turnstile ('B031', 'R172', '01-06-03', 'BRIGHTON BEACH')
# Processing turnstile ('B032', 'R264', '00-00-00', 'OCEAN PKWY')
# Processing turnstile ('B032', 'R264', '00-00-01', 'OCEAN PKWY')
# Processing turnstile ('B032', 'R264', '00-00-02', 'OCEAN PKWY')
# Processing turnstile ('B034', 'R264', '01-05-00', 'OCEAN PKWY')
# Processing turnstile ('B034', 'R264', '01-05-01', 'OCEAN PKWY')
# Processing turnstile ('B034', 'R264', '01-06-00', 'OCEAN PKWY')
# Processing turnstile ('B034', 'R264', '01-06-01', 'OCEAN PKWY')
# Processing turnstile ('C001', 'R108', '01-00-00', 'BOROUGH HALL')
# Processing turnstile ('C001', 'R108', '01-00-01', 'BOROUGH HALL')
# Processing turnstile ('C001', 'R108', '01-00-02', 'BOROUGH HALL')
# Processing turnstile ('C001', 'R108', '01-06-00', 'BOROUGH HALL')
# Processing turnstile ('C001', 'R108', '01-06-01', 'BOROUGH HALL')
# Processing turnstile ('C003', 'R089', '00-00-00', 'JAY ST-METROTEC')
# Processing turnstile ('C003', 'R089', '00-00-01', 'JAY ST-METROTEC')
# Processing turnstile ('C003', 'R089', '00-00-02', 'JAY ST-METROTEC')
# Processing turnstile ('C003', 'R089', '00-03-00', 'JAY ST-METROTEC')
# Processing turnstile ('C003', 'R089', '00-03-01', 'JAY ST-METROTEC')
# Processing turnstile ('C004', 'R089', '01-05-00', 'JAY ST-METROTEC')
# Processing turnstile ('C004', 'R089', '01-05-01', 'JAY ST-METROTEC')
# Processing turnstile ('C004', 'R089', '01-06-00', 'JAY ST-METROTEC')
# Processing turnstile ('C004', 'R089', '01-06-01', 'JAY ST-METROTEC')
# Processing turnstile ('C008', 'R099', '00-00-00', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-00-01', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-00-02', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-00-03', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-03-00', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-03-01', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-03-02', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-03-03', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-03-04', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-04-00', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-04-01', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-06-00', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-06-01', 'DEKALB AV')
# Processing turnstile ('C008', 'R099', '00-06-02', 'DEKALB AV')
# Processing turnstile ('C009', 'R057', '03-00-00', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-00-01', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-00-02', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-00-03', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-03-00', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-03-01', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-03-02', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-03-03', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-05-00', 'ATL AV-BARCLAY')
# Processing turnstile ('C009', 'R057', '03-05-01', 'ATL AV-BARCLAY')
# Processing turnstile ('C010', 'R231', '00-00-00', 'UNION ST')
# Processing turnstile ('C010', 'R231', '00-00-01', 'UNION ST')
# Processing turnstile ('C010', 'R231', '00-00-02', 'UNION ST')
# Processing turnstile ('C011', 'R231', '01-00-00', 'UNION ST')
# Processing turnstile ('C011', 'R231', '01-00-01', 'UNION ST')
# Processing turnstile ('C011', 'R231', '01-00-02', 'UNION ST')
# Processing turnstile ('C012', 'R258', '01-00-00', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-00-01', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-00-02', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-00-03', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-03-00', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-03-02', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-03-03', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-06-00', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-06-01', '4AV-9 ST')
# Processing turnstile ('C012', 'R258', '01-06-02', '4AV-9 ST')
# Processing turnstile ('C014', 'R246', '00-00-00', 'PROSPECT AV')
# Processing turnstile ('C014', 'R246', '00-00-01', 'PROSPECT AV')
# Processing turnstile ('C014', 'R246', '00-00-02', 'PROSPECT AV')
# Processing turnstile ('C015', 'R454', '00-00-00', 'PROSPECT AV')
# Processing turnstile ('C015', 'R454', '00-00-01', 'PROSPECT AV')
# Processing turnstile ('C015', 'R454', '00-00-02', 'PROSPECT AV')
# Processing turnstile ('C016', 'R278', '00-00-00', '25 ST')
# Processing turnstile ('C016', 'R278', '00-00-01', '25 ST')
# Processing turnstile ('C016', 'R278', '00-00-02', '25 ST')
# Processing turnstile ('C017', 'R455', '00-00-00', '25 ST')
# Processing turnstile ('C017', 'R455', '00-00-01', '25 ST')
# Processing turnstile ('C017', 'R455', '00-00-02', '25 ST')
# Processing turnstile ('C018', 'R197', '00-00-00', '36 ST')
# Processing turnstile ('C018', 'R197', '00-00-01', '36 ST')
# Processing turnstile ('C018', 'R197', '00-00-02', '36 ST')
# Processing turnstile ('C018', 'R197', '00-00-03', '36 ST')
# Processing turnstile ('C018', 'R197', '00-00-04', '36 ST')
# Processing turnstile ('C018', 'R197', '00-00-05', '36 ST')
# Processing turnstile ('C019', 'R232', '00-00-00', '45 ST')
# Processing turnstile ('C019', 'R232', '00-00-01', '45 ST')
# Processing turnstile ('C019', 'R232', '00-00-02', '45 ST')
# Processing turnstile ('C019', 'R232', '00-00-03', '45 ST')
# Processing turnstile ('C021', 'R212', '00-00-00', '59 ST')
# Processing turnstile ('C021', 'R212', '00-00-01', '59 ST')
# Processing turnstile ('C021', 'R212', '00-00-02', '59 ST')
# Warning: Abnormal entry count found on day 2017-04-30: -2042
# Warning: Abnormal entry count found on day 2017-05-01: -1568
# Warning: Abnormal entry count found on day 2017-05-02: -3142
# Warning: Abnormal entry count found on day 2017-05-03: -3096
# Warning: Abnormal entry count found on day 2017-05-04: -3666
# Warning: Abnormal entry count found on day 2017-05-05: -3006
# Warning: Abnormal entry count found on day 2017-05-06: -2759
# Warning: Abnormal entry count found on day 2017-05-07: -1874
# Warning: Abnormal entry count found on day 2017-05-08: -1419
# Warning: Abnormal entry count found on day 2017-05-09: -2991
# Warning: Abnormal entry count found on day 2017-05-10: -2811
# Warning: Abnormal entry count found on day 2017-05-11: -2977
# Warning: Abnormal entry count found on day 2017-05-12: -2957
# Warning: Abnormal entry count found on day 2017-05-13: -3036
# Warning: Abnormal entry count found on day 2017-05-14: -1759
# Warning: Abnormal entry count found on day 2017-05-15: -1556
# Warning: Abnormal entry count found on day 2017-05-16: -2970
# Warning: Abnormal entry count found on day 2017-05-17: -3088
# Warning: Abnormal entry count found on day 2017-05-18: -2922
# Warning: Abnormal entry count found on day 2017-05-19: -3430
# Warning: Abnormal entry count found on day 2017-05-20: -2980
# Warning: Abnormal entry count found on day 2017-05-21: -1713
# Warning: Abnormal entry count found on day 2017-05-22: -1346
# Warning: Abnormal entry count found on day 2017-05-23: -2899
# Warning: Abnormal entry count found on day 2017-05-24: -2954
# Warning: Abnormal entry count found on day 2017-05-25: -2938
# Warning: Abnormal entry count found on day 2017-05-26: -2915
# Processing turnstile ('C021', 'R212', '00-00-03', '59 ST')
# Processing turnstile ('C022', 'R212', '01-03-00', '59 ST')
# Processing turnstile ('C022', 'R212', '01-05-00', '59 ST')
# Processing turnstile ('C022', 'R212', '01-05-01', '59 ST')
# Processing turnstile ('C022', 'R212', '01-06-00', '59 ST')
# Processing turnstile ('C022', 'R212', '01-06-01', '59 ST')
# Processing turnstile ('C023', 'R213', '00-00-00', 'BAY RIDGE AV')
# Processing turnstile ('C023', 'R213', '00-00-01', 'BAY RIDGE AV')
# Processing turnstile ('C023', 'R213', '00-00-02', 'BAY RIDGE AV')
# Processing turnstile ('C023', 'R213', '00-00-03', 'BAY RIDGE AV')
# Processing turnstile ('C023', 'R213', '00-00-04', 'BAY RIDGE AV')
# Processing turnstile ('C023', 'R213', '00-00-05', 'BAY RIDGE AV')
# Processing turnstile ('C024', 'R214', '00-00-00', '77 ST')
# Processing turnstile ('C024', 'R214', '00-00-01', '77 ST')
# Processing turnstile ('C024', 'R214', '00-00-02', '77 ST')
# Processing turnstile ('C024', 'R214', '00-00-03', '77 ST')
# Processing turnstile ('C025', 'R215', '00-00-00', '86 ST')
# Processing turnstile ('C025', 'R215', '00-00-01', '86 ST')
# Processing turnstile ('C025', 'R215', '00-03-00', '86 ST')
# Processing turnstile ('C025', 'R215', '00-03-01', '86 ST')
# Processing turnstile ('C025', 'R215', '00-03-02', '86 ST')
# Processing turnstile ('C026', 'R215', '01-05-00', '86 ST')
# Processing turnstile ('C026', 'R215', '01-05-01', '86 ST')
# Processing turnstile ('C026', 'R215', '01-06-00', '86 ST')
# Processing turnstile ('C026', 'R215', '01-06-01', '86 ST')
# Processing turnstile ('C027', 'R216', '00-00-00', 'BAY RIDGE-95 ST')
# Processing turnstile ('C027', 'R216', '00-00-01', 'BAY RIDGE-95 ST')
# Processing turnstile ('C027', 'R216', '00-00-02', 'BAY RIDGE-95 ST')
# Processing turnstile ('C027', 'R216', '00-03-00', 'BAY RIDGE-95 ST')
# Processing turnstile ('C027', 'R216', '00-03-01', 'BAY RIDGE-95 ST')
# Processing turnstile ('C028', 'R216', '01-05-00', 'BAY RIDGE-95 ST')
# Processing turnstile ('C028', 'R216', '01-05-01', 'BAY RIDGE-95 ST')
# Processing turnstile ('C028', 'R216', '01-06-00', 'BAY RIDGE-95 ST')
# Processing turnstile ('C028', 'R216', '01-06-01', 'BAY RIDGE-95 ST')
# Processing turnstile ('D002', 'R390', '00-00-00', '8 AV')
# Processing turnstile ('D002', 'R390', '00-00-01', '8 AV')
# Processing turnstile ('D002', 'R390', '00-00-02', '8 AV')
# Processing turnstile ('D002', 'R390', '00-03-00', '8 AV')
# Processing turnstile ('D002', 'R390', '00-03-01', '8 AV')
# Processing turnstile ('D002', 'R390', '00-03-02', '8 AV')
# Processing turnstile ('D003', 'R391', '00-00-00', 'FT HAMILTON PKY')
# Processing turnstile ('D003', 'R391', '00-00-01', 'FT HAMILTON PKY')
# Processing turnstile ('D003', 'R391', '00-00-02', 'FT HAMILTON PKY')
# Processing turnstile ('D005', 'R398', '00-00-00', 'NEW UTRECHT AV')
# Processing turnstile ('D005', 'R398', '00-00-01', 'NEW UTRECHT AV')
# Processing turnstile ('D005', 'R398', '00-00-02', 'NEW UTRECHT AV')
# Processing turnstile ('D005', 'R398', '00-06-00', 'NEW UTRECHT AV')
# Processing turnstile ('D005', 'R398', '00-06-01', 'NEW UTRECHT AV')
# Processing turnstile ('D008', 'R392', '00-00-00', '18 AV')
# Processing turnstile ('D008', 'R392', '00-00-01', '18 AV')
# Processing turnstile ('D008', 'R392', '00-00-02', '18 AV')
# Processing turnstile ('D009', 'R393', '00-00-00', '20 AV')
# Processing turnstile ('D009', 'R393', '00-00-01', '20 AV')
# Processing turnstile ('D009', 'R393', '00-00-02', '20 AV')
# Processing turnstile ('D010', 'R394', '00-00-00', 'BAY PKWY')
# Processing turnstile ('D010', 'R394', '00-00-01', 'BAY PKWY')
# Processing turnstile ('D010', 'R394', '00-00-02', 'BAY PKWY')
# Processing turnstile ('D010', 'R394', '00-00-03', 'BAY PKWY')
# Processing turnstile ('D012', 'R395', '00-00-00', 'KINGS HWY')
# Processing turnstile ('D012', 'R395', '00-00-01', 'KINGS HWY')
# Processing turnstile ('D012', 'R395', '00-00-02', 'KINGS HWY')
# Processing turnstile ('D015', 'R396', '00-00-00', 'AVENUE U')
# Processing turnstile ('D015', 'R396', '00-00-01', 'AVENUE U')
# Processing turnstile ('D015', 'R396', '00-00-02', 'AVENUE U')
# Processing turnstile ('D016', 'R397', '00-00-00', '86 ST')
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST')
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV')
# Processing turnstile ('E001', 'R368', '00-00-01', '9 AV')
# ...
# Warning: Abnormal entry count found on day 2017-05-03: -4231
# Warning: Abnormal entry count found on day 2017-05-04: -4324
# Warning: Abnormal entry count found on day 2017-05-05: -4171
# Warning: Abnormal entry count found on day 2017-05-06: -3803
# Warning: Abnormal entry count found on day 2017-05-07: -2449
# Warning: Abnormal entry count found on day 2017-05-08: -2067
# Warning: Abnormal entry count found on day 2017-05-09: -3787
# Warning: Abnormal entry count found on day 2017-05-10: -3958
# Warning: Abnormal entry count found on day 2017-05-11: -4087
# Warning: Abnormal entry count found on day 2017-05-12: -2671
# Warning: Abnormal entry count found on day 2017-05-13: -4288
# Warning: Abnormal entry count found on day 2017-05-14: -2283
# Warning: Abnormal entry count found on day 2017-05-15: -1925
# Warning: Abnormal entry count found on day 2017-05-16: -3714
# Warning: Abnormal entry count found on day 2017-05-17: -3941
# Warning: Abnormal entry count found on day 2017-05-18: -4011
# Warning: Abnormal entry count found on day 2017-05-19: -4057
# Warning: Abnormal entry count found on day 2017-05-20: -4210
# Warning: Abnormal entry count found on day 2017-05-21: -2728
# Warning: Abnormal entry count found on day 2017-05-22: -2065
# Warning: Abnormal entry count found on day 2017-05-23: -3497
# Warning: Abnormal entry count found on day 2017-05-24: -3921
# Warning: Abnormal entry count found on day 2017-05-25: -3909
# Warning: Abnormal entry count found on day 2017-05-26: -3646
# Processing turnstile ('R622', 'R123', '00-00-01', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-02', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-03', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-04', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-05', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-06', 'FRANKLIN AV')
# Processing turnstile ('R622', 'R123', '00-00-07', 'FRANKLIN AV')
# Processing turnstile ('R623', 'R061', '00-00-00', 'NOSTRAND AV')
# Processing turnstile ('R623', 'R061', '00-00-01', 'NOSTRAND AV')
# Processing turnstile ('R623', 'R061', '00-00-02', 'NOSTRAND AV')
# Processing turnstile ('R624', 'R124', '00-00-00', 'KINGSTON AV')
# Processing turnstile ('R624', 'R124', '00-00-01', 'KINGSTON AV')
# Processing turnstile ('R624', 'R124', '00-00-02', 'KINGSTON AV')
# Processing turnstile ('R625', 'R062', '01-00-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-00-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-00-02', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-00-03', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-06-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-06-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R625', 'R062', '01-06-02', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-00-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-00-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-00-02', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-00-03', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-00-04', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-03-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-03-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-03-02', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-03-03', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-05-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R626', 'R062', '00-05-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R628', 'R064', '00-00-00', 'SARATOGA AV')
# Processing turnstile ('R628', 'R064', '00-00-01', 'SARATOGA AV')
# Processing turnstile ('R628', 'R064', '00-00-02', 'SARATOGA AV')
# Processing turnstile ('R628', 'R064', '00-00-03', 'SARATOGA AV')
# Processing turnstile ('R628', 'R064', '00-00-04', 'SARATOGA AV')
# Processing turnstile ('R629', 'R065', '00-00-00', 'ROCKAWAY AV')
# Processing turnstile ('R629', 'R065', '00-00-01', 'ROCKAWAY AV')
# Processing turnstile ('R629', 'R065', '00-00-02', 'ROCKAWAY AV')
# Processing turnstile ('R629', 'R065', '00-03-00', 'ROCKAWAY AV')
# Processing turnstile ('R629', 'R065', '00-03-01', 'ROCKAWAY AV')
# Processing turnstile ('R629', 'R065', '00-03-02', 'ROCKAWAY AV')
# Processing turnstile ('R632', 'R067', '00-00-00', 'PENNSYLVANIA AV')
# Processing turnstile ('R632', 'R067', '00-00-01', 'PENNSYLVANIA AV')
# Processing turnstile ('R632', 'R067', '00-00-02', 'PENNSYLVANIA AV')
# Processing turnstile ('R632', 'R067', '00-00-03', 'PENNSYLVANIA AV')
# Processing turnstile ('R633', 'R068', '00-00-00', 'VAN SICLEN AV')
# Processing turnstile ('R633', 'R068', '00-00-01', 'VAN SICLEN AV')
# Processing turnstile ('R633', 'R068', '00-00-02', 'VAN SICLEN AV')
# Processing turnstile ('R633', 'R068', '00-00-03', 'VAN SICLEN AV')
# Processing turnstile ('R634', 'R069', '00-00-00', 'NEW LOTS AV')
# Processing turnstile ('R634', 'R069', '00-00-01', 'NEW LOTS AV')
# Processing turnstile ('R634', 'R069', '00-00-02', 'NEW LOTS AV')
# Processing turnstile ('R634', 'R069', '00-03-00', 'NEW LOTS AV')
# Processing turnstile ('R634', 'R069', '00-03-01', 'NEW LOTS AV')
# Processing turnstile ('R634', 'R069', '00-03-02', 'NEW LOTS AV')
# Processing turnstile ('R635', 'R277', '00-00-00', 'PRESIDENT ST')
# Processing turnstile ('R635', 'R277', '00-00-01', 'PRESIDENT ST')
# Processing turnstile ('R635', 'R277', '00-00-02', 'PRESIDENT ST')
# Processing turnstile ('R636', 'R209', '00-00-00', 'STERLING ST')
# Processing turnstile ('R636', 'R209', '00-00-01', 'STERLING ST')
# Processing turnstile ('R636', 'R209', '00-00-02', 'STERLING ST')
# Processing turnstile ('R637', 'R451', '00-00-00', 'WINTHROP ST')
# Processing turnstile ('R637', 'R451', '00-00-01', 'WINTHROP ST')
# Processing turnstile ('R637', 'R451', '00-00-02', 'WINTHROP ST')
# Processing turnstile ('R637', 'R451', '00-06-00', 'WINTHROP ST')
# Processing turnstile ('R639', 'R109', '00-00-00', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-00-01', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-00-02', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-00-03', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-05-00', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-05-01', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-05-02', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-05-03', 'CHURCH AV')
# Processing turnstile ('R639', 'R109', '00-06-00', 'CHURCH AV')
# Processing turnstile ('R641', 'R210', '00-00-00', 'BEVERLY RD')
# Processing turnstile ('R641', 'R210', '00-00-01', 'BEVERLY RD')
# Processing turnstile ('R641', 'R210', '00-00-02', 'BEVERLY RD')
# Processing turnstile ('R641', 'R210', '00-06-00', 'BEVERLY RD')
# Processing turnstile ('R643', 'R135', '00-00-00', 'NEWKIRK AV')
# Processing turnstile ('R643', 'R135', '00-00-01', 'NEWKIRK AV')
# Processing turnstile ('R643', 'R135', '00-00-02', 'NEWKIRK AV')
# Processing turnstile ('R643', 'R135', '00-03-00', 'NEWKIRK AV')
# Processing turnstile ('R644', 'R135', '01-00-00', 'NEWKIRK AV')
# Processing turnstile ('R644', 'R135', '01-00-01', 'NEWKIRK AV')
# Processing turnstile ('R644', 'R135', '01-00-02', 'NEWKIRK AV')
# Processing turnstile ('R644', 'R135', '01-06-00', 'NEWKIRK AV')
# Processing turnstile ('R644', 'R135', '01-06-01', 'NEWKIRK AV')
# Processing turnstile ('R645', 'R110', '00-00-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-00-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-00-02', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-03-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-03-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-03-02', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-05-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-05-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-06-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-06-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R645', 'R110', '00-06-02', 'FLATBUSH AV-B.C')
# Processing turnstile ('R646', 'R110', '01-00-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R646', 'R110', '01-00-01', 'FLATBUSH AV-B.C')
# Warning: Abnormal entry count found on day 2017-04-30: -606
# Warning: Abnormal entry count found on day 2017-05-01: -448
# Warning: Abnormal entry count found on day 2017-05-02: -2262
# Warning: Abnormal entry count found on day 2017-05-03: -2114
# Warning: Abnormal entry count found on day 2017-05-04: -2185
# Warning: Abnormal entry count found on day 2017-05-05: -2142
# Warning: Abnormal entry count found on day 2017-05-06: -1541
# Warning: Abnormal entry count found on day 2017-05-07: -641
# Warning: Abnormal entry count found on day 2017-05-08: -437
# Warning: Abnormal entry count found on day 2017-05-09: -2071
# Warning: Abnormal entry count found on day 2017-05-10: -2297
# Warning: Abnormal entry count found on day 2017-05-11: -2183
# Warning: Abnormal entry count found on day 2017-05-12: -2127
# Warning: Abnormal entry count found on day 2017-05-13: -1750
# Warning: Abnormal entry count found on day 2017-05-14: -580
# Warning: Abnormal entry count found on day 2017-05-15: -397
# Warning: Abnormal entry count found on day 2017-05-16: -2131
# Warning: Abnormal entry count found on day 2017-05-17: -2240
# Warning: Abnormal entry count found on day 2017-05-18: -2884
# Warning: Abnormal entry count found on day 2017-05-19: -2175
# Warning: Abnormal entry count found on day 2017-05-20: -1809
# Warning: Abnormal entry count found on day 2017-05-21: -631
# Warning: Abnormal entry count found on day 2017-05-22: -506
# Warning: Abnormal entry count found on day 2017-05-23: -1926
# Warning: Abnormal entry count found on day 2017-05-24: -2065
# Warning: Abnormal entry count found on day 2017-05-25: -2041
# Warning: Abnormal entry count found on day 2017-05-26: -1850
# Processing turnstile ('R646', 'R110', '01-00-02', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-00-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-00-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-05-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-05-01', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-05-02', 'FLATBUSH AV-B.C')
# Processing turnstile ('R647', 'R110', '02-06-00', 'FLATBUSH AV-B.C')
# Processing turnstile ('R726', 'R329', '00-00-00', 'MORRIS PARK')
# Processing turnstile ('R726', 'R329', '00-00-01', 'MORRIS PARK')
# Processing turnstile ('R726', 'R329', '00-00-02', 'MORRIS PARK')
# Processing turnstile ('R727', 'R430', '00-00-00', 'PELHAM PKWY')
# Processing turnstile ('R727', 'R430', '00-00-01', 'PELHAM PKWY')
# Processing turnstile ('R727', 'R430', '00-00-02', 'PELHAM PKWY')
# Processing turnstile ('R728', 'R226', '00-00-00', 'GUN HILL RD')
# Processing turnstile ('R728', 'R226', '00-00-01', 'GUN HILL RD')
# Processing turnstile ('R728', 'R226', '00-00-02', 'GUN HILL RD')
# Processing turnstile ('R728', 'R226', '00-00-03', 'GUN HILL RD')
# Processing turnstile ('R729', 'R292', '00-00-00', 'BAYCHESTER AV')
# Processing turnstile ('R729', 'R292', '00-00-01', 'BAYCHESTER AV')
# Processing turnstile ('R729', 'R292', '00-00-02', 'BAYCHESTER AV')
# Processing turnstile ('R730', 'R431', '00-00-00', 'EASTCHSTER/DYRE')
# Processing turnstile ('R730', 'R431', '00-00-01', 'EASTCHSTER/DYRE')
# Processing turnstile ('R730', 'R431', '00-00-02', 'EASTCHSTER/DYRE')
# Processing turnstile ('R730', 'R431', '00-00-03', 'EASTCHSTER/DYRE')
# Processing turnstile ('R730', 'R431', '00-00-04', 'EASTCHSTER/DYRE')
# Warning: Abnormal entry count found on day 2017-05-05: 1557696408
# Warning: Abnormal entry count found on day 2017-05-06: -217
# Warning: Abnormal entry count found on day 2017-05-07: -2
# Warning: Abnormal entry count found on day 2017-05-09: -518
# Warning: Abnormal entry count found on day 2017-05-10: -534
# Warning: Abnormal entry count found on day 2017-05-11: -524
# Warning: Abnormal entry count found on day 2017-05-12: -492
# Warning: Abnormal entry count found on day 2017-05-13: -472
# Warning: Abnormal entry count found on day 2017-05-16: -579
# Warning: Abnormal entry count found on day 2017-05-17: -522
# Warning: Abnormal entry count found on day 2017-05-18: -541
# Warning: Abnormal entry count found on day 2017-05-19: -508
# Warning: Abnormal entry count found on day 2017-05-20: -524
# Warning: Abnormal entry count found on day 2017-05-23: -484
# Warning: Abnormal entry count found on day 2017-05-24: -540
# Warning: Abnormal entry count found on day 2017-05-25: -550
# Warning: Abnormal entry count found on day 2017-05-26: -519
# Processing turnstile ('S101', 'R070', '00-00-00', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-01', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-02', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-03', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-04', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-05', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-06', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-07', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-00-08', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-03-00', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-03-01', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-03-02', 'ST. GEORGE')
# Processing turnstile ('S101', 'R070', '00-03-03', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-00', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-01', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-02', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-03', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-04', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-05', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-00-06', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-03-00', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-03-01', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-03-02', 'ST. GEORGE')
# Warning: Abnormal entry count found on day 2017-05-14: -534659
# Processing turnstile ('S101A', 'R070', '01-03-03', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-05-00', 'ST. GEORGE')
# Processing turnstile ('S101A', 'R070', '01-05-01', 'ST. GEORGE')
# Processing turnstile ('S102', 'R165', '00-00-00', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-00-01', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-03-00', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-03-01', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-03-02', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-05-00', 'TOMPKINSVILLE')
# Processing turnstile ('S102', 'R165', '00-05-01', 'TOMPKINSVILLE')
# Processing turnstile ('TRAM1', 'R468', '00-00-00', 'RIT-MANHATTAN')
# Processing turnstile ('TRAM1', 'R468', '00-00-01', 'RIT-MANHATTAN')
# Processing turnstile ('TRAM1', 'R468', '00-00-02', 'RIT-MANHATTAN')
# Processing turnstile ('TRAM1', 'R468', '00-05-00', 'RIT-MANHATTAN')
# Processing turnstile ('TRAM2', 'R469', '00-00-00', 'RIT-ROOSEVELT')
# Processing turnstile ('TRAM2', 'R469', '00-00-01', 'RIT-ROOSEVELT')
# Processing turnstile ('TRAM2', 'R469', '00-03-00', 'RIT-ROOSEVELT')
# Processing turnstile ('TRAM2', 'R469', '00-03-01', 'RIT-ROOSEVELT')
# Processing turnstile ('TRAM2', 'R469', '00-05-00', 'RIT-ROOSEVELT')
# Processing turnstile ('TRAM2', 'R469', '00-05-01', 'RIT-ROOSEVELT')
# Processing turnstile ('PTH08', 'R540', '00-00-00', 'PATH WTC')
# Processing turnstile ('R633', 'R068', '00-00-C6', 'VAN SICLEN AV')
# Processing turnstile ('N551', 'R421', '00-06-01', 'AVENUE I')
# Processing turnstile ('N559', 'R425', '00-06-01', 'AVENUE U')
# Processing turnstile ('OB01', 'R459', '00-00-00', 'ORCHARD BEACH')
# Processing turnstile ('OB01', 'R459', '00-00-01', 'ORCHARD BEACH')
# Processing turnstile ('OB01', 'R459', '00-00-02', 'ORCHARD BEACH')
# Processing turnstile ('OB01', 'R459', '00-03-00', 'ORCHARD BEACH')
# Processing turnstile ('OB01', 'R459', '00-03-01', 'ORCHARD BEACH')

# %%
pprint(daily_time_series[('A006', 'R079', '00-00-03', '5 AV/59 ST')])
# Out:
# [(datetime.date(2017, 4, 29), None),
#  (datetime.date(2017, 4, 30), 409),
#  (datetime.date(2017, 5, 1), 1021),
#  (datetime.date(2017, 5, 2), 1071),
#  (datetime.date(2017, 5, 3), 1094),
#  (datetime.date(2017, 5, 4), 1097),
#  (datetime.date(2017, 5, 5), 840),
#  (datetime.date(2017, 5, 6), 527),
#  (datetime.date(2017, 5, 7), 384),
#  (datetime.date(2017, 5, 8), 975),
#  (datetime.date(2017, 5, 9), 1060),
#  (datetime.date(2017, 5, 10), 1092),
#  (datetime.date(2017, 5, 11), 1090),
#  (datetime.date(2017, 5, 12), 973),
#  (datetime.date(2017, 5, 13), 411),
#  (datetime.date(2017, 5, 14), 520),
#  (datetime.date(2017, 5, 15), 1015),
#  (datetime.date(2017, 5, 16), 1124),
#  (datetime.date(2017, 5, 17), 1160),
#  (datetime.date(2017, 5, 18), 1121),
#  (datetime.date(2017, 5, 19), 1128),
#  (datetime.date(2017, 5, 20), 539),
#  (datetime.date(2017, 5, 21), 575),
#  (datetime.date(2017, 5, 22), 939),
#  (datetime.date(2017, 5, 23), 1025),
#  (datetime.date(2017, 5, 24), 1076),
#  (datetime.date(2017, 5, 25), 1055),
#  (datetime.date(2017, 5, 26), 840)]

# %% [markdown]
# ## Exercise 4
# - We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the notebook.
# To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

dates = []
counts = []

for date, entries in daily_time_series[('A006', 'R079', '00-00-03', '5 AV/59 ST')]:
    dates.append(date)
    counts.append(entries)

plt.figure(figsize=(10,3))
plt.plot(dates,counts)

# %% [markdown]
# ## Exercise 5
# - So far we've been operating on a single turnstile level, let's combine turnstiles in the same ControlArea/Unit/Station combo. There are some ControlArea/Unit/Station groups that have a single turnstile, but most have multiple turnstilea-- same value for the C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo.

# %%
from collections import Counter

def booth_of_item(item):
    turnstile, time_series = item
    control_area, unit, device_id, station = turnstile
    return (control_area, unit, station)
    

turnstile_time_series_items = sorted(daily_time_series.items())
booth_series = {}

for booth, item_list_of_booth in groupby(turnstile_time_series_items, key=booth_of_item):
    daily_counter = Counter()

    for turnstile, time_series in item_list_of_booth:
        for day, count in time_series:
            if count is not None:
                    daily_counter[day] += count

    booth_series[booth] = sorted(daily_counter.items())

pprint(booth_series[('A011', 'R080', '57 ST-7 AV')])
# Out:
# [(datetime.date(2017, 4, 30), 5752),
#  (datetime.date(2017, 5, 1), 11358),
#  (datetime.date(2017, 5, 2), 12297),
#  (datetime.date(2017, 5, 3), 12548),
#  (datetime.date(2017, 5, 4), 12238),
#  (datetime.date(2017, 5, 5), 12133),
#  (datetime.date(2017, 5, 6), 6877),
#  (datetime.date(2017, 5, 7), 5601),
#  (datetime.date(2017, 5, 8), 11169),
#  (datetime.date(2017, 5, 9), 12464),
#  (datetime.date(2017, 5, 10), 13218),
#  (datetime.date(2017, 5, 11), 12803),
#  (datetime.date(2017, 5, 12), 12857),
#  (datetime.date(2017, 5, 13), 7857),
#  (datetime.date(2017, 5, 14), 5790),
#  (datetime.date(2017, 5, 15), 11408),
#  (datetime.date(2017, 5, 16), 12487),
#  (datetime.date(2017, 5, 17), 12923),
#  (datetime.date(2017, 5, 18), 13549),
#  (datetime.date(2017, 5, 19), 12742),
#  (datetime.date(2017, 5, 20), 7785),
#  (datetime.date(2017, 5, 21), 6828),
#  (datetime.date(2017, 5, 22), 11920),
#  (datetime.date(2017, 5, 23), 12393),
#  (datetime.date(2017, 5, 24), 13311),
#  (datetime.date(2017, 5, 25), 13911),
#  (datetime.date(2017, 5, 26), 11619)]

# %% [markdown]
# ## Exercise 6
# - Similarly, combine everything in each station, and come up with a time series of `[(date1, count1),(date2,count2),...]` type of time series for each STATION, by adding up all the turnstiles in a station.

# %%
def return_station(item):
    booth, entries = item
    control_area, unit, station = booth
    
    return station

sorted_booth_series = sorted(booth_series.items())
booth_to_station = {}

for station, item_list in groupby(sorted_booth_series, key=return_station):
    daily_counter = Counter()
    
    for booth, time_series in item_list:
        for day, count in time_series:
            daily_counter[day] += count
                
    booth_to_station[station] = sorted(daily_counter.items())

# %%
pprint(booth_to_station['14 ST'])
# Out:
# [(datetime.date(2017, 4, 30), 20462),
#  (datetime.date(2017, 5, 1), 21161),
#  (datetime.date(2017, 5, 2), 22937),
#  (datetime.date(2017, 5, 3), 23793),
#  (datetime.date(2017, 5, 4), 24425),
#  (datetime.date(2017, 5, 5), 22668),
#  (datetime.date(2017, 5, 6), 19145),
#  (datetime.date(2017, 5, 7), 16603),
#  (datetime.date(2017, 5, 8), 20451),
#  (datetime.date(2017, 5, 9), 22796),
#  (datetime.date(2017, 5, 10), 23227),
#  (datetime.date(2017, 5, 11), 24122),
#  (datetime.date(2017, 5, 12), 23881),
#  (datetime.date(2017, 5, 13), 17710),
#  (datetime.date(2017, 5, 14), 16357),
#  (datetime.date(2017, 5, 15), 21502),
#  (datetime.date(2017, 5, 16), 22886),
#  (datetime.date(2017, 5, 17), 23770),
#  (datetime.date(2017, 5, 18), 23866),
#  (datetime.date(2017, 5, 19), 24312),
#  (datetime.date(2017, 5, 20), 20358),
#  (datetime.date(2017, 5, 21), 18064),
#  (datetime.date(2017, 5, 22), 19796),
#  (datetime.date(2017, 5, 23), 21905),
#  (datetime.date(2017, 5, 24), 24522),
#  (datetime.date(2017, 5, 25), 22507),
#  (datetime.date(2017, 5, 26), 21237)]

# %% [markdown]
# ## Exercise 7
# - Plot the time series for a station

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
dates = []
counts = []

for date, count in booth_to_station['14 ST']:
    dates.append(date)
    counts.append(count)

# %%
def plot_station_entries(station, station_series):
    time_series = station_series[station]
    dates, counts = zip(*time_series) # uncouples a set of tuples into lists 
    plt.figure(figsize=(15,5))
    plt.plot(dates,counts)
    plt.xlabel('Date')
    plt.ylabel('Station Entries')
    plt.title('Daily entries for {} Station'.format(station))

# %%
plot_station_entries('14 ST', booth_to_station)

# %% [markdown]
# ## Exercise 8
# - Make one list of counts for **one** week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another week.
# `plt.plot(week_count_list)` for every `week_count_list` you created this way. You should get a rainbow plot of weekly commute numbers on top of each other.

# %%
import numpy as np

days_of_the_week = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Fiday', 5:'Saturday', 6:'Sunday'}

def separate_weeks(time_series):
    week = []
    time_series_for_each_week = []
    
    for i, (day, count) in enumerate(time_series):
        week.append((day, count))

        if i % 7 == 6:
            time_series_for_each_week.append(week)
            week = []
        
    time_series_for_each_week.append(week)
    return time_series_for_each_week

def return_day_of_week(date):
    
    day_int = date.weekday()
    return days_of_the_week[day_int]

def rainbow_plot(station_name, station_series):
    time_series = station_series[station_name]
    time_series_for_each_week = separate_weeks(time_series)
    
    plt.figure(figsize=(15, 3))
    for week in time_series_for_each_week:
        days, counts = zip(*week)
        days = range(len(counts))
        plt.plot(days, counts)
    
    plt.xlabel('Day of the week')
    plt.ylabel('Total entries')
    plt.xticks(np.arange(7), ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat'])
    plt.title('Ridership at {}'.format(station_name))

# %%
rainbow_plot('14 ST', booth_to_station)

# %% [markdown]
# ## Exercise 9
# - Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate

# %% [markdown]
# ## Exercise 10
# - Make a single list of these total ridership values and plot it with `plt.hist(total_ridership_counts)` to get an idea about the distribution of total ridership among different stations.
# This should show you that most stations have a small traffic, and the histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
# If you want to see which stations take the meat of the traffic, you can sort the total ridership counts and make a `plt.bar` graph. For this, you want to have two lists: the indices of each bar, and the values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)
